# %% [markdown]
# # Data Cleaning and Merging Notebook

# %% [markdown]
# Notes on data cleaning / merging. The objective of the work in this notebook is to merge the various metrics we want to use into one dataset which we can then use for run analysis on. We will not at this stage be removing null values as where one metric might be missing values another will not and depending on what metrics we're looking to run the analysis we might not care about data missing in another metric. Removing null values will happen at the analysis point depending on what analysis / relationships is being explored. Hence most mergers are done as 'outer' merges.
#
# Only data which is removed at this stage is data for years earlier than 2010, as that is when our main Internet Penetration dataset starts and countries which are not included in the Internet Penetration dataset.
#
# Data is sourced through CSVs and APIs, some challenges included: different spellings of countries so needing to join several datasets with ISO codes to match properly.

# %% [markdown]
# ## Table of Contents
# 1. [Internet Penetration Data Cleaning - csv](#internetcleaning)
# 2. [GNI Data Cleaning and Merging - csv](#gnicleaning)
# 3. [GINI Index Data Cleaning and Merging - csv](#ginicleaning)
# 4. [GDP Data Cleaning and Merging - csv](#gdpcleaning)
# 5. [Happiness Index Cleaning and Merging - csv](#happinesindexcleaning)
# 6. [Literacy Rates Cleaning and Merging - api](#literacyratescleaning)
# 7. [Suicide Rates Cleaning and Merging - api](#suicideratescleaning)
# 8. [CO2 Emissions Cleaning and Merging - api](#co2cleaning)
# 9. [Internet Price Data Cleaning and Merging](#ipcleaning)
# 10. [Voter Turnout Cleaning and Merging](#VoterTurnout)
# 11. [Final Data Export](#finalexport)

# %% [markdown]
# ## Internet Penetration Data Cleaning <a name="internetcleaning"></a>
# Pulling in and setting up the data from the ITU dataset on Internet Peneration rates by country by year

# %%
import requests
import pandas as pd

internet_data = pd.read_excel("data/ddd_dataset.xlsx")
internet_data.head()
# Out:
#        Country          Region  ISO  \
# 0  Afghanistan  Asia & Pacific  AFG
# 1  Afghanistan  Asia & Pacific  AFG
# 2  Afghanistan  Asia & Pacific  AFG
# 3  Afghanistan  Asia & Pacific  AFG
# 4  Afghanistan  Asia & Pacific  AFG
#
#                                       Indicator name  Year        Value  \
# 0  Active mobile-broadband subscriptions per 100 ...  2010     0.000000
# 1  Fixed broadband subscriptions per 100 inhabitants  2010     0.005321
# 2  Fixed-telephone subscriptions per 100 inhabitants  2010     0.058958
# 3          Individuals using the Internet, total (%)  2010     4.000000
# 4  International bandwidth per Internet user (kbi...  2010  1773.699247
#
#   ITU estimate?
# 0           NaN
# 1           NaN
# 2           NaN
# 3           yes
# 4           NaN

# %%
internet_data.shape
# Out:
# (41045, 7)

# %%
internet_data_pivot = internet_data.pivot_table(index=['Country', 'Region', 'ISO', 'Year'], columns='Indicator name', values='Value').reset_index()
internet_data_pivot.columns
# Out:
# Index(['Country', 'Region', 'ISO', 'Year',
#        'Active mobile-broadband subscriptions per 100 inhabitants',
#        'Female Internet users as a % of total female population',
#        'Female mobile phone ownership as a % of total female population',
#        'Fixed broadband basket as a % of GNI p.c.',
#        'Fixed broadband subscriptions per 100 inhabitants',
#        'Fixed broadband subscriptions: 2 to 10 Mbit/s',
#        'Fixed broadband subscriptions: 256kbit/s - <2Mbit/s',
#        'Fixed broadband subscriptions: >10 Mbit/s',
#        'Fixed-telephone subscriptions per 100 inhabitants',
#        'Households with Internet access at home (%)',
#        'Households with Internet access at home, rural (%)',
#        'Households with Internet access at home, urban (%)',
#        'Households with a computer at home (%)',
#        'Individuals owning a mobile phone (%)',
#        'Individuals using the Internet, total (%)',
#        'International bandwidth per Internet user (kbit/s)',
#        'Internet users: 15-24 years as a % of all 15-24 years',
#        'Internet users: 25-74 years as a % of all 25-74 years',
#        'Internet users: 75+ years as a % of all 75+ years',
#        'Internet users: < 15 years as a % of all < 15 years',
#        'Male Internet users as a % of total male population',
#        'Male mobile phone ownership as a % of total male population',
#        'Mobile broadband basket as a % of GNI p.c.',
#        'Mobile cellular basket as a % of GNI p.c.',
#        'Mobile data and voice basket (high consumption) as a % of GNI p.c.',
#        'Mobile data and voice basket (low consumption) as a % of GNI p.c.',
#        'Mobile-cellular subscriptions per 100 inhabitants',
#        'Monthly fixed broadband Internet traffic per fixed broadband subscription (MB)',
#        'Monthly mobile broadband Internet traffic per mobile broadband subscription (MB)',
#        'Population covered by a mobile-cellular network (%)',
#        'Population covered by at least a 3G mobile network (%)',
#        'Population covered by at least a 4G mobile network (%)',
#        'Total fixed broadband subscriptions'],
#       dtype='object', name='Indicator name')

# %%
columns_keep = [
    'Country', 'Region', 'ISO', 'Year',
    'Individuals using the Internet, total (%)'
]

internet_df = internet_data_pivot.loc[:, columns_keep]
internet_df
# Out:
# Indicator name      Country          Region  ISO  Year  \
# 0               Afghanistan  Asia & Pacific  AFG  2010
# 1               Afghanistan  Asia & Pacific  AFG  2011
# 2               Afghanistan  Asia & Pacific  AFG  2012
# 3               Afghanistan  Asia & Pacific  AFG  2013
# 4               Afghanistan  Asia & Pacific  AFG  2014
# ...                     ...             ...  ...   ...
# 2531               Zimbabwe          Africa  ZWE  2018
# 2532               Zimbabwe          Africa  ZWE  2019
# 2533               Zimbabwe          Africa  ZWE  2020
# 2534               Zimbabwe          Africa  ZWE  2021
# 2535               Zimbabwe          Africa  ZWE  2022
#
# Indicator name  Individuals using the Internet, total (%)
# 0                                                4.000000
# 1                                                5.000000
# 2                                                5.454545
# 3                                                5.900000
# 4                                                7.000000
# ...                                                   ...
# 2531                                            25.000000
# 2532                                            26.588274
# 2533                                            29.298565
# 2534                                            34.813971
# 2535                                                  NaN
#
# [2536 rows x 5 columns]

# %%
internet_df.describe()
# Out:
# Indicator name         Year  Individuals using the Internet, total (%)
# count           2536.000000                                2303.000000
# mean            2016.003155                                  50.239339
# std                3.743869                                  30.182481
# min             2010.000000                                   0.000000
# 25%             2013.000000                                  22.126371
# 50%             2016.000000                                  52.570000
# 75%             2019.000000                                  77.793618
# max             2022.000000                                 100.000000

# %%
internet_df.shape
# Out:
# (2536, 5)

# %% [markdown]
# Name of final dataframe at this stage is internet_df

# %% [markdown]
# ## GNI Data Cleaning and Merging <a name="gnicleaning"></a>
# Pulling in and setting up the data from the world bank dataset on GNI index by country by year.

# %%
gni_initial_dataset = pd.read_csv("data/API_NY.GNP.PCAP.CD_DS2_en_csv_v2_5995153.csv", skiprows=4)
gni_initial_dataset.describe()
# Out:
#        1960  1961         1962         1963         1964         1965  \
# count   0.0   0.0    91.000000    95.000000   100.000000   100.000000
# mean    NaN   NaN   531.029978   548.675836   577.470411   625.984096
# std     NaN   NaN   668.348745   696.089995   739.005508   803.617720
# min     NaN   NaN    40.000000    30.000000    30.000000    20.000000
# 25%     NaN   NaN   116.540047   120.000000   130.000000   138.121516
# 50%     NaN   NaN   230.000000   230.000000   225.000000   250.000000
# 75%     NaN   NaN   600.000000   630.000000   670.000000   707.500000
# max     NaN   NaN  3280.000000  3410.000000  3610.000000  3880.000000
#
#               1966         1967         1968         1969  ...           2014  \
# count   106.000000   116.000000   121.000000   123.000000  ...     246.000000
# mean    655.325566   678.725735   732.203761   777.301303  ...   14614.966827
# std     855.350719   889.517219   963.207138  1035.314350  ...   19999.177897
# min      20.000000    10.000000    10.000000    20.000000  ...     250.000000
# 25%     150.000000   155.878350   162.886992   165.000000  ...    2005.509921
# 50%     270.000000   280.000000   300.000000   300.000000  ...    6272.843434
# 75%     725.000000   720.000000   750.000000   805.000000  ...   16065.000000
# max    4190.000000  4370.000000  4740.000000  5070.000000  ...  105070.000000
#
#                 2015           2016           2017           2018  \
# count     247.000000     246.000000     247.000000     247.000000
# mean    13906.813772   13499.390230   13604.672333   14521.260807
# std     18883.747206   18275.606286   18435.882072   19611.637771
# min       250.000000     250.000000     250.000000     240.000000
# 25%      2009.744307    2020.861033    1990.000000    1980.000000
# 50%      5960.000000    5695.000000    5770.000000    6160.000000
# 75%     15960.000000   16342.500000   16460.000000   17320.000000
# max    101120.000000  103620.000000  112940.000000  117000.000000
#
#                 2019           2020           2021           2022  Unnamed: 67
# count     247.000000     244.000000     242.000000     230.000000          0.0
# mean    15269.493880   14246.927678   15243.050960   15634.511279          NaN
# std     20239.705223   19210.726095   20485.527531   21309.703328          NaN
# min       230.000000     220.000000     220.000000     240.000000          NaN
# 25%      2095.000000    2090.000000    2177.500000    2234.391723          NaN
# 50%      6505.791615    6010.000000    6344.792244    6770.000000          NaN
# 75%     18000.000000   16795.000000   17995.000000   18845.000000          NaN
# max    117280.000000  111800.000000  120020.000000  125240.000000          NaN
#
# [8 rows x 64 columns]

# %%
gni_initial_dataset.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                Indicator Name  Indicator Code  1960  1961  \
# 0  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 1  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 2  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 3  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 4  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
#
#          1962        1963        1964        1965  ...          2014  \
# 0         NaN         NaN         NaN         NaN  ...  25790.000000
# 1         NaN         NaN         NaN         NaN  ...   1696.462899
# 2         NaN         NaN         NaN         NaN  ...    650.000000
# 3  113.080093  121.446289  127.515314  132.486065  ...   2101.336153
# 4         NaN         NaN         NaN         NaN  ...   4800.000000
#
#            2015          2016          2017          2018          2019  \
# 0  26180.000000  26650.000000  27720.000000  29310.000000  30330.000000
# 1   1579.295342   1460.609129   1443.996026   1456.396534   1494.589953
# 2    610.000000    570.000000    540.000000    520.000000    530.000000
# 3   2009.488614   1776.140878   1590.799458   1606.960024   1681.824079
# 4   3880.000000   2450.000000   1980.000000   1870.000000   2040.000000
#
#            2020          2021         2022  Unnamed: 67
# 0  24840.000000  29460.000000          NaN          NaN
# 1   1388.531225   1461.388019  1542.260985          NaN
# 2    500.000000    390.000000          NaN          NaN
# 3   1664.742718   1727.603209  1779.431390          NaN
# 4   1690.000000   1650.000000  1900.000000          NaN
#
# [5 rows x 68 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
gni_initial_dataset.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              266
# 1961              266
# 1962              175
# 1963              171
# 1964              166
# 1965              166
# 1966              160
# 1967              150
# 1968              145
# 1969              143
# 1970              144
# 1971              144
# 1972              133
# 1973              132
# 1974              132
# 1975              133
# 1976              132
# 1977              131
# 1978              128
# 1979              123
# 1980              118
# 1981              117
# 1982              104
# 1983               99
# 1984               96
# 1985               94
# 1986               91
# 1987               91
# 1988               89
# 1989               86
# 1990               83
# 1991               82
# 1992               70
# 1993               64
# 1994               61
# 1995               52
# 1996               50
# 1997               40
# 1998               40
# 1999               40
# 2000               37
# 2001               38
# 2002               29
# 2003               28
# 2004               28
# 2005               28
# 2006               27
# 2007               27
# 2008               28
# 2009               27
# 2010               24
# 2011               23
# 2012               23
# 2013               21
# 2014               20
# 2015               19
# 2016               20
# 2017               19
# 2018               19
# 2019               19
# 2020               22
# 2021               24
# 2022               36
# Unnamed: 67       266
# dtype: int64

# %% [markdown]
# Given we only have internet penetration data from 2010 and the effects of internet would take some time be realised, we'll definitely get rid of all the data from before 2010 as thats where most of the data is missing as well as the column called 'unnamed: 67' as it's all blanks.

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)
gni_unpivot_dataset = pd.melt(gni_initial_dataset, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                       var_name='Year', value_name='Value')

gni_unpivot_dataset
# Out:
#                       Country Name Country Code  \
# 0                            Aruba          ABW
# 1      Africa Eastern and Southern          AFE
# 2                      Afghanistan          AFG
# 3       Africa Western and Central          AFW
# 4                           Angola          AGO
# ...                            ...          ...
# 17019                       Kosovo          XKX
# 17020                  Yemen, Rep.          YEM
# 17021                 South Africa          ZAF
# 17022                       Zambia          ZMB
# 17023                     Zimbabwe          ZWE
#
#                                    Indicator Name  Indicator Code  \
# 0      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 1      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 2      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 3      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 4      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# ...                                           ...             ...
# 17019  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 17020  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 17021  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 17022  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
# 17023  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD
#
#               Year  Value
# 0             1960    NaN
# 1             1960    NaN
# 2             1960    NaN
# 3             1960    NaN
# 4             1960    NaN
# ...            ...    ...
# 17019  Unnamed: 67    NaN
# 17020  Unnamed: 67    NaN
# 17021  Unnamed: 67    NaN
# 17022  Unnamed: 67    NaN
# 17023  Unnamed: 67    NaN
#
# [17024 rows x 6 columns]

# %%
# gni_relevant_years = gni_unpivot_dataset[(gni_unpivot_dataset['Year'] >= 2010) & (gni_unpivot_dataset['Year'] != 'Unnamed: 67')]
# gni_relevant_years

# Not able to use this approach as the year is stored as a string so will get rid of the Unnamed:67 rows first and then convert that column into integer values
gni_years_only = gni_unpivot_dataset[(gni_unpivot_dataset['Year'] != 'Unnamed: 67')]
gni_years_only
# Out:
#                       Country Name Country Code  \
# 0                            Aruba          ABW
# 1      Africa Eastern and Southern          AFE
# 2                      Afghanistan          AFG
# 3       Africa Western and Central          AFW
# 4                           Angola          AGO
# ...                            ...          ...
# 16753                       Kosovo          XKX
# 16754                  Yemen, Rep.          YEM
# 16755                 South Africa          ZAF
# 16756                       Zambia          ZMB
# 16757                     Zimbabwe          ZWE
#
#                                    Indicator Name  Indicator Code  Year  \
# 0      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  1960
# 1      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  1960
# 2      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  1960
# 3      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  1960
# 4      GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  1960
# ...                                           ...             ...   ...
# 16753  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16754  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16755  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16756  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16757  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
#
#         Value
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 16753  5590.0
# 16754     NaN
# 16755  6780.0
# 16756  1170.0
# 16757  1500.0
#
# [16758 rows x 6 columns]

# %% [markdown]
# Now changing the year column to integers so we can cut out the years but a simple less than argument

# %%
gni_years_only.loc[:, 'Year'] = gni_years_only['Year'].astype(int)
gni_years_only.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# Year               object
# Value             float64
# dtype: object

# %% [markdown]
# Have two options here for changing the data type of integer as sometimes one of them don't work.

# %%
gni_years_only['Year'] = pd.to_numeric(gni_years_only['Year'], errors='coerce')
gni_years_only.dtypes
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3982770618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gni_years_only['Year'] = pd.to_numeric(gni_years_only['Year'], errors='coerce')
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# Year                int64
# Value             float64
# dtype: object

# %% [markdown]
# Now that the year column is converted we can create a new dataset filtering out the years we don't need.

# %%
gni_relevant_years = gni_years_only[(gni_years_only['Year'] >= 2010)]
gni_relevant_years
# Out:
#                       Country Name Country Code  \
# 13300                        Aruba          ABW
# 13301  Africa Eastern and Southern          AFE
# 13302                  Afghanistan          AFG
# 13303   Africa Western and Central          AFW
# 13304                       Angola          AGO
# ...                            ...          ...
# 16753                       Kosovo          XKX
# 16754                  Yemen, Rep.          YEM
# 16755                 South Africa          ZAF
# 16756                       Zambia          ZMB
# 16757                     Zimbabwe          ZWE
#
#                                    Indicator Name  Indicator Code  Year  \
# 13300  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2010
# 13301  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2010
# 13302  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2010
# 13303  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2010
# 13304  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2010
# ...                                           ...             ...   ...
# 16753  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16754  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16755  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16756  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
# 16757  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  2022
#
#               Value
# 13300  23390.000000
# 13301   1438.818933
# 13302    520.000000
# 13303   1559.231753
# 13304   3210.000000
# ...             ...
# 16753   5590.000000
# 16754           NaN
# 16755   6780.000000
# 16756   1170.000000
# 16757   1500.000000
#
# [3458 rows x 6 columns]

# %%
merged_df = pd.merge(internet_df, gni_relevant_years[['Country Code', 'Year', 'Value']], how='outer', left_on=['ISO', 'Year'], right_on=['Country Code', 'Year'])
merged_df = merged_df.rename(columns={'Value': 'GNI per capita'})
merged_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 3469          NaN             NaN  NaN  2022
# 3470          NaN             NaN  NaN  2022
# 3471          NaN             NaN  NaN  2022
# 3472          NaN             NaN  NaN  2022
# 3473          NaN             NaN  NaN  2022
#
#       Individuals using the Internet, total (%) Country Code  GNI per capita
# 0                                      4.000000          AFG      520.000000
# 1                                      5.000000          AFG      550.000000
# 2                                      5.454545          AFG      650.000000
# 3                                      5.900000          AFG      680.000000
# 4                                      7.000000          AFG      650.000000
# ...                                         ...          ...             ...
# 3469                                        NaN          UMC    10529.880203
# 3470                                        NaN          VGB             NaN
# 3471                                        NaN          VIR             NaN
# 3472                                        NaN          WLD    12803.872147
# 3473                                        NaN          XKX     5590.000000
#
# [3474 rows x 7 columns]

# %% [markdown]
# The GNI Index had some regional groups, socioeconomic groups and countries with the UN doesn't recognize and weren't included in the internet penetration dataset so I want to remove all the rows where the Country / Region / ISO is blank, they seem to all be the same rows, 938 of them.

# %%
empty_country_df = merged_df[merged_df['Country'].isnull()]
empty_country_df
# Out:
#      Country Region  ISO  Year  Individuals using the Internet, total (%)  \
# 2536     NaN    NaN  NaN  2010                                        NaN
# 2537     NaN    NaN  NaN  2010                                        NaN
# 2538     NaN    NaN  NaN  2010                                        NaN
# 2539     NaN    NaN  NaN  2010                                        NaN
# 2540     NaN    NaN  NaN  2010                                        NaN
# ...      ...    ...  ...   ...                                        ...
# 3469     NaN    NaN  NaN  2022                                        NaN
# 3470     NaN    NaN  NaN  2022                                        NaN
# 3471     NaN    NaN  NaN  2022                                        NaN
# 3472     NaN    NaN  NaN  2022                                        NaN
# 3473     NaN    NaN  NaN  2022                                        NaN
#
#      Country Code  GNI per capita
# 2536          ABW    23390.000000
# 2537          AFE     1438.818933
# 2538          AFW     1559.231753
# 2539          ARB     6168.562166
# 2540          ASM             NaN
# ...           ...             ...
# 3469          UMC    10529.880203
# 3470          VGB             NaN
# 3471          VIR             NaN
# 3472          WLD    12803.872147
# 3473          XKX     5590.000000
#
# [938 rows x 7 columns]

# %% [markdown]
# Finding all codes which don't have corresponding code the internet data and the creating a dictionary to make sure we're happy to drop all those areas and that they do in fact correspond to regions / sub regions / aggregates etc.

# %%
codes_to_drop = []
country_codes = merged_df['Country Code'].tolist()
iso_codes = merged_df['ISO'].tolist()

for code in country_codes:
    if code not in iso_codes:
        codes_to_drop.append(code)

country_code_country_dict = dict(zip(gni_relevant_years['Country Code'], gni_relevant_years['Country Name']))

filtered_dict = {key: value for key, value in country_code_country_dict.items() if key in codes_to_drop}
filtered_dict
# Out:
# {'ABW': 'Aruba',
#  'AFE': 'Africa Eastern and Southern',
#  'AFW': 'Africa Western and Central',
#  'ARB': 'Arab World',
#  'ASM': 'American Samoa',
#  'BMU': 'Bermuda',
#  'CEB': 'Central Europe and the Baltics',
#  'CHI': 'Channel Islands',
#  'CSS': 'Caribbean small states',
#  'CUW': 'Curacao',
#  'CYM': 'Cayman Islands',
#  'EAP': 'East Asia & Pacific (excluding high income)',
#  'EAR': 'Early-demographic dividend',
#  'EAS': 'East Asia & Pacific',
#  'ECA': 'Europe & Central Asia (excluding high income)',
#  'ECS': 'Europe & Central Asia',
#  'EMU': 'Euro area',
#  'EUU': 'European Union',
#  'FCS': 'Fragile and conflict affected situations',
#  'FRO': 'Faroe Islands',
#  'GIB': 'Gibraltar',
#  'GRL': 'Greenland',
#  'GUM': 'Guam',
#  'HIC': 'High income',
#  'HPC': 'Heavily indebted poor countries (HIPC)',
#  'IBD': 'IBRD only',
#  'IBT': 'IDA & IBRD total',
#  'IDA': 'IDA total',
#  'IDB': 'IDA blend',
#  'IDX': 'IDA only',
#  'IMN': 'Isle of Man',
#  'INX': 'Not classified',
#  'LAC': 'Latin America & Caribbean (excluding high income)',
#  'LCN': 'Latin America & Caribbean',
#  'LDC': 'Least developed countries: UN classification',
#  'LIC': 'Low income',
#  'LMC': 'Lower middle income',
#  'LMY': 'Low & middle income',
#  'LTE': 'Late-demographic dividend',
#  'MAF': 'St. Martin (French part)',
#  'MEA': 'Middle East & North Africa',
#  'MIC': 'Middle income',
#  'MNA': 'Middle East & North Africa (excluding high income)',
#  'MNP': 'Northern Mariana Islands',
#  'NAC': 'North America',
#  'NCL': 'New Caledonia',
#  'OED': 'OECD members',
#  'OSS': 'Other small states',
#  'PLW': 'Palau',
#  'PRE': 'Pre-demographic dividend',
#  'PRI': 'Puerto Rico',
#  'PSE': 'West Bank and Gaza',
#  'PSS': 'Pacific island small states',
#  'PST': 'Post-demographic dividend',
#  'PYF': 'French Polynesia',
#  'SAS': 'South Asia',
#  'SSA': 'Sub-Saharan Africa (excluding high income)',
#  'SSF': 'Sub-Saharan Africa',
#  'SST': 'Small states',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'TCA': 'Turks and Caicos Islands',
#  'TEA': 'East Asia & Pacific (IDA & IBRD countries)',
#  'TEC': 'Europe & Central Asia (IDA & IBRD countries)',
#  'TLA': 'Latin America & the Caribbean (IDA & IBRD countries)',
#  'TMN': 'Middle East & North Africa (IDA & IBRD countries)',
#  'TSA': 'South Asia (IDA & IBRD)',
#  'TSS': 'Sub-Saharan Africa (IDA & IBRD countries)',
#  'UMC': 'Upper middle income',
#  'VGB': 'British Virgin Islands',
#  'VIR': 'Virgin Islands (U.S.)',
#  'WLD': 'World',
#  'XKX': 'Kosovo'}

# %% [markdown]
# Having scanned this filtered list dictionary, happy to remove all rows corresponding to these country codes in the merged dataset.

# %%
internet_gni_df = merged_df[~merged_df['Country Code'].isin(codes_to_drop)]
internet_gni_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2533     Zimbabwe          Africa  ZWE  2020
# 2534     Zimbabwe          Africa  ZWE  2021
# 2535     Zimbabwe          Africa  ZWE  2022
# 3129          NaN             NaN  NaN  2018
# 3164          NaN             NaN  NaN  2018
#
#       Individuals using the Internet, total (%) Country Code  GNI per capita
# 0                                      4.000000          AFG           520.0
# 1                                      5.000000          AFG           550.0
# 2                                      5.454545          AFG           650.0
# 3                                      5.900000          AFG           680.0
# 4                                      7.000000          AFG           650.0
# ...                                         ...          ...             ...
# 2533                                  29.298565          ZWE          1460.0
# 2534                                  34.813971          ZWE          1530.0
# 2535                                        NaN          ZWE          1500.0
# 3129                                        NaN          ERI             NaN
# 3164                                        NaN          PRK             NaN
#
# [2538 rows x 7 columns]

# %% [markdown]
# Now need to fill in Country, Region, ISO columns where we have the GNI metric, or at a least a row came in from that dataset for that year but that country / year combination wasn't in the dataset originally.

# %%
country_code_info_dict = dict(zip(internet_gni_df['ISO'], zip(internet_gni_df['Country'], internet_gni_df['Region'])))
country_code_info_dict
# Out:
# {'AFG': ('Afghanistan', 'Asia & Pacific'),
#  'ALB': ('Albania', 'Europe'),
#  'DZA': ('Algeria', 'Arab States'),
#  'AND': ('Andorra', 'Europe'),
#  'AGO': ('Angola', 'Africa'),
#  'ATG': ('Antigua and Barbuda', 'The Americas'),
#  'ARG': ('Argentina', 'The Americas'),
#  'ARM': ('Armenia', 'CIS'),
#  'AUS': ('Australia', 'Asia & Pacific'),
#  'AUT': ('Austria', 'Europe'),
#  'AZE': ('Azerbaijan', 'CIS'),
#  'BHS': ('Bahamas', 'The Americas'),
#  'BHR': ('Bahrain', 'Arab States'),
#  'BGD': ('Bangladesh', 'Asia & Pacific'),
#  'BRB': ('Barbados', 'The Americas'),
#  'BLR': ('Belarus', 'CIS'),
#  'BEL': ('Belgium', 'Europe'),
#  'BLZ': ('Belize', 'The Americas'),
#  'BEN': ('Benin', 'Africa'),
#  'BTN': ('Bhutan', 'Asia & Pacific'),
#  'BOL': ('Bolivia (Plurinational State of)', 'The Americas'),
#  'BIH': ('Bosnia and Herzegovina', 'Europe'),
#  'BWA': ('Botswana', 'Africa'),
#  'BRA': ('Brazil', 'The Americas'),
#  'BRN': ('Brunei Darussalam', 'Asia & Pacific'),
#  'BGR': ('Bulgaria', 'Europe'),
#  'BFA': ('Burkina Faso', 'Africa'),
#  'BDI': ('Burundi', 'Africa'),
#  'CPV': ('Cabo Verde', 'Africa'),
#  'KHM': ('Cambodia', 'Asia & Pacific'),
#  'CMR': ('Cameroon', 'Africa'),
#  'CAN': ('Canada', 'The Americas'),
#  'CAF': ('Central African Rep.', 'Africa'),
#  'TCD': ('Chad', 'Africa'),
#  'CHL': ('Chile', 'The Americas'),
#  'CHN': ('China', 'Asia & Pacific'),
#  'COL': ('Colombia', 'The Americas'),
#  'COM': ('Comoros', 'Arab States'),
#  'COG': ('Congo (Rep. of the)', 'Africa'),
#  'CRI': ('Costa Rica', 'The Americas'),
#  'HRV': ('Croatia', 'Europe'),
#  'CUB': ('Cuba', 'The Americas'),
#  'CYP': ('Cyprus', 'Europe'),
#  'CZE': ('Czech Republic', 'Europe'),
#  'CIV': ("Côte d'Ivoire", 'Africa'),
#  'PRK': ("Dem. People's Rep. of Korea", 'Asia & Pacific'),
#  'COD': ('Dem. Rep. of the Congo', 'Africa'),
#  'DNK': ('Denmark', 'Europe'),
#  'DJI': ('Djibouti', 'Arab States'),
#  'DMA': ('Dominica', 'The Americas'),
#  'DOM': ('Dominican Rep.', 'The Americas'),
#  'ECU': ('Ecuador', 'The Americas'),
#  'EGY': ('Egypt', 'Arab States'),
#  'SLV': ('El Salvador', 'The Americas'),
#  'GNQ': ('Equatorial Guinea', 'Africa'),
#  'ERI': ('Eritrea', 'Africa'),
#  'EST': ('Estonia', 'Europe'),
#  'SWZ': ('Eswatini', 'Africa'),
#  'ETH': ('Ethiopia', 'Africa'),
#  'FJI': ('Fiji', 'Asia & Pacific'),
#  'FIN': ('Finland', 'Europe'),
#  'FRA': ('France', 'Europe'),
#  'GAB': ('Gabon', 'Africa'),
#  'GMB': ('Gambia', 'Africa'),
#  'GEO': ('Georgia', 'Europe'),
#  'DEU': ('Germany', 'Europe'),
#  'GHA': ('Ghana', 'Africa'),
#  'GRC': ('Greece', 'Europe'),
#  'GRD': ('Grenada', 'The Americas'),
#  'GTM': ('Guatemala', 'The Americas'),
#  'GIN': ('Guinea', 'Africa'),
#  'GNB': ('Guinea-Bissau', 'Africa'),
#  'GUY': ('Guyana', 'The Americas'),
#  'HTI': ('Haiti', 'The Americas'),
#  'HND': ('Honduras', 'The Americas'),
#  'HKG': ('Hong Kong, China', 'Asia & Pacific'),
#  'HUN': ('Hungary', 'Europe'),
#  'ISL': ('Iceland', 'Europe'),
#  'IND': ('India', 'Asia & Pacific'),
#  'IDN': ('Indonesia', 'Asia & Pacific'),
#  'IRN': ('Iran (Islamic Republic of)', 'Asia & Pacific'),
#  'IRQ': ('Iraq', 'Arab States'),
#  'IRL': ('Ireland', 'Europe'),
#  'ISR': ('Israel', 'Europe'),
#  'ITA': ('Italy', 'Europe'),
#  'JAM': ('Jamaica', 'The Americas'),
#  'JPN': ('Japan', 'Asia & Pacific'),
#  'JOR': ('Jordan', 'Arab States'),
#  'KAZ': ('Kazakhstan', 'CIS'),
#  'KEN': ('Kenya', 'Africa'),
#  'KIR': ('Kiribati', 'Asia & Pacific'),
#  'KOR': ('Korea (Rep. of)', 'Asia & Pacific'),
#  'KWT': ('Kuwait', 'Arab States'),
#  'KGZ': ('Kyrgyzstan', 'CIS'),
#  'LAO': ('Lao P.D.R.', 'Asia & Pacific'),
#  'LVA': ('Latvia', 'Europe'),
#  'LBN': ('Lebanon', 'Arab States'),
#  'LSO': ('Lesotho', 'Africa'),
#  'LBR': ('Liberia', 'Africa'),
#  'LBY': ('Libya', 'Arab States'),
#  'LIE': ('Liechtenstein', 'Europe'),
#  'LTU': ('Lithuania', 'Europe'),
#  'LUX': ('Luxembourg', 'Europe'),
#  'MAC': ('Macao, China', 'Asia & Pacific'),
#  'MDG': ('Madagascar', 'Africa'),
#  'MWI': ('Malawi', 'Africa'),
#  'MYS': ('Malaysia', 'Asia & Pacific'),
#  'MDV': ('Maldives', 'Asia & Pacific'),
#  'MLI': ('Mali', 'Africa'),
#  'MLT': ('Malta', 'Europe'),
#  'MHL': ('Marshall Islands', 'Asia & Pacific'),
#  'MRT': ('Mauritania', 'Arab States'),
#  'MUS': ('Mauritius', 'Africa'),
#  'MEX': ('Mexico', 'The Americas'),
#  'FSM': ('Micronesia', 'Asia & Pacific'),
#  'MDA': ('Moldova', 'Europe'),
#  'MCO': ('Monaco', 'Europe'),
#  'MNG': ('Mongolia', 'Asia & Pacific'),
#  'MNE': ('Montenegro', 'Europe'),
#  'MAR': ('Morocco', 'Arab States'),
#  'MOZ': ('Mozambique', 'Africa'),
#  'MMR': ('Myanmar', 'Asia & Pacific'),
#  'NAM': ('Namibia', 'Africa'),
#  'NRU': ('Nauru', 'Asia & Pacific'),
#  'NPL': ('Nepal (Republic of)', 'Asia & Pacific'),
#  'NLD': ('Netherlands', 'Europe'),
#  'NZL': ('New Zealand', 'Asia & Pacific'),
#  'NIC': ('Nicaragua', 'The Americas'),
#  'NER': ('Niger', 'Africa'),
#  'NGA': ('Nigeria', 'Africa'),
#  'MKD': ('North Macedonia', 'Europe'),
#  'NOR': ('Norway', 'Europe'),
#  'OMN': ('Oman', 'Arab States'),
#  'PAK': ('Pakistan', 'Asia & Pacific'),
#  'WBG': ('Palestine', 'Arab States'),
#  'PAN': ('Panama', 'The Americas'),
#  'PNG': ('Papua New Guinea', 'Asia & Pacific'),
#  'PRY': ('Paraguay', 'The Americas'),
#  'PER': ('Peru', 'The Americas'),
#  'PHL': ('Philippines', 'Asia & Pacific'),
#  'POL': ('Poland', 'Europe'),
#  'PRT': ('Portugal', 'Europe'),
#  'QAT': ('Qatar', 'Arab States'),
#  'ROU': ('Romania', 'Europe'),
#  'RUS': ('Russian Federation', 'CIS'),
#  'RWA': ('Rwanda', 'Africa'),
#  'KNA': ('Saint Kitts and Nevis', 'The Americas'),
#  'LCA': ('Saint Lucia', 'The Americas'),
#  'VCT': ('Saint Vincent and the Grenadines', 'The Americas'),
#  'WSM': ('Samoa', 'Asia & Pacific'),
#  'SMR': ('San Marino', 'Europe'),
#  'STP': ('Sao Tome and Principe', 'Africa'),
#  'SAU': ('Saudi Arabia', 'Arab States'),
#  'SEN': ('Senegal', 'Africa'),
#  'SRB': ('Serbia', 'Europe'),
#  'SYC': ('Seychelles', 'Africa'),
#  'SLE': ('Sierra Leone', 'Africa'),
#  'SGP': ('Singapore', 'Asia & Pacific'),
#  'SVK': ('Slovakia', 'Europe'),
#  'SVN': ('Slovenia', 'Europe'),
#  'SLB': ('Solomon Islands', 'Asia & Pacific'),
#  'SOM': ('Somalia', 'Arab States'),
#  'ZAF': ('South Africa', 'Africa'),
#  'SSD': ('South Sudan', 'Africa'),
#  'ESP': ('Spain', 'Europe'),
#  'LKA': ('Sri Lanka', 'Asia & Pacific'),
#  'SDN': ('Sudan', 'Arab States'),
#  'SUR': ('Suriname', 'The Americas'),
#  'SWE': ('Sweden', 'Europe'),
#  'CHE': ('Switzerland', 'Europe'),
#  'SYR': ('Syrian Arab Republic', 'Arab States'),
#  'TJK': ('Tajikistan', 'CIS'),
#  'TZA': ('Tanzania', 'Africa'),
#  'THA': ('Thailand', 'Asia & Pacific'),
#  'TLS': ('Timor-Leste', 'Asia & Pacific'),
#  'TGO': ('Togo', 'Africa'),
#  'TON': ('Tonga', 'Asia & Pacific'),
#  'TTO': ('Trinidad and Tobago', 'The Americas'),
#  'TUN': ('Tunisia', 'Arab States'),
#  'TKM': ('Turkmenistan', 'CIS'),
#  'TUV': ('Tuvalu', 'Asia & Pacific'),
#  'TUR': ('Türkiye', 'Europe'),
#  'UGA': ('Uganda', 'Africa'),
#  'UKR': ('Ukraine', 'Europe'),
#  'ARE': ('United Arab Emirates', 'Arab States'),
#  'GBR': ('United Kingdom', 'Europe'),
#  'USA': ('United States', 'The Americas'),
#  'URY': ('Uruguay', 'The Americas'),
#  'UZB': ('Uzbekistan', 'CIS'),
#  'VUT': ('Vanuatu', 'Asia & Pacific'),
#  'VAT': ('Vatican', 'Europe'),
#  'VEN': ('Venezuela', 'The Americas'),
#  'VNM': ('Viet Nam', 'Asia & Pacific'),
#  'YEM': ('Yemen', 'Arab States'),
#  'ZMB': ('Zambia', 'Africa'),
#  'ZWE': ('Zimbabwe', 'Africa'),
#  nan: (nan, nan)}

# %%
for index, row in internet_gni_df.iterrows():
    iso_code = row["Country Code"]
    if iso_code in country_code_info_dict:
        country_name, region = country_code_info_dict[iso_code]
        if pd.isnull(row["Country"]):
            internet_gni_df.at[index, "Country"] = country_name
        if pd.isnull(row["Region"]):
            internet_gni_df.at[index, "Region"] = region
        if pd.isnull(row["ISO"]):
            internet_gni_df.at[index, "ISO"] = iso_code

internet_gni_df
# Out:
#                           Country          Region  ISO  Year  \
# 0                     Afghanistan  Asia & Pacific  AFG  2010
# 1                     Afghanistan  Asia & Pacific  AFG  2011
# 2                     Afghanistan  Asia & Pacific  AFG  2012
# 3                     Afghanistan  Asia & Pacific  AFG  2013
# 4                     Afghanistan  Asia & Pacific  AFG  2014
# ...                           ...             ...  ...   ...
# 2533                     Zimbabwe          Africa  ZWE  2020
# 2534                     Zimbabwe          Africa  ZWE  2021
# 2535                     Zimbabwe          Africa  ZWE  2022
# 3129                      Eritrea          Africa  ERI  2018
# 3164  Dem. People's Rep. of Korea  Asia & Pacific  PRK  2018
#
#       Individuals using the Internet, total (%) Country Code  GNI per capita
# 0                                      4.000000          AFG           520.0
# 1                                      5.000000          AFG           550.0
# 2                                      5.454545          AFG           650.0
# 3                                      5.900000          AFG           680.0
# 4                                      7.000000          AFG           650.0
# ...                                         ...          ...             ...
# 2533                                  29.298565          ZWE          1460.0
# 2534                                  34.813971          ZWE          1530.0
# 2535                                        NaN          ZWE          1500.0
# 3129                                        NaN          ERI             NaN
# 3164                                        NaN          PRK             NaN
#
# [2538 rows x 7 columns]

# %% [markdown]
# checking that it implemented properly

# %%
pd.set_option("display.max_rows", None)
internet_gni_df[internet_gni_df["Country Code"]=="ERI"]
# Out:
#       Country  Region  ISO  Year  Individuals using the Internet, total (%)  \
# 714   Eritrea  Africa  ERI  2010                                   0.610000
# 715   Eritrea  Africa  ERI  2011                                   0.700000
# 716   Eritrea  Africa  ERI  2012                                   0.800000
# 717   Eritrea  Africa  ERI  2013                                   0.900000
# 718   Eritrea  Africa  ERI  2014                                   0.990000
# 719   Eritrea  Africa  ERI  2015                                   1.083733
# 720   Eritrea  Africa  ERI  2016                                   1.177119
# 721   Eritrea  Africa  ERI  2017                                   1.308907
# 722   Eritrea  Africa  ERI  2019                                   8.832308
# 723   Eritrea  Africa  ERI  2020                                  14.179987
# 724   Eritrea  Africa  ERI  2021                                  21.730386
# 725   Eritrea  Africa  ERI  2022                                        NaN
# 3129  Eritrea  Africa  ERI  2018                                        NaN
#
#      Country Code  GNI per capita
# 714           ERI           520.0
# 715           ERI           610.0
# 716           ERI             NaN
# 717           ERI             NaN
# 718           ERI             NaN
# 719           ERI             NaN
# 720           ERI             NaN
# 721           ERI             NaN
# 722           ERI             NaN
# 723           ERI             NaN
# 724           ERI             NaN
# 725           ERI             NaN
# 3129          ERI             NaN

# %%
internet_gni_df.shape
# Out:
# (2538, 7)

# %% [markdown]
# Final dataframe after this section is called: internet_gni_df

# %% [markdown]
# ## GINI Index Data Cleaning <a name="ginicleaning"></a>
# Pulling in and setting up the data from the world bank dataset on GINI coefficient by country by year.

# %%
pd.set_option('display.max_rows', 10)
gini_initial_data = pd.read_csv("data/API_SI.POV.GINI_DS2_en_csv_v2_5994673.csv", skiprows=4)
gini_initial_data
# Out:
#                     Country Name Country Code Indicator Name Indicator Code  \
# 0                          Aruba          ABW     Gini index    SI.POV.GINI
# 1    Africa Eastern and Southern          AFE     Gini index    SI.POV.GINI
# 2                    Afghanistan          AFG     Gini index    SI.POV.GINI
# 3     Africa Western and Central          AFW     Gini index    SI.POV.GINI
# 4                         Angola          AGO     Gini index    SI.POV.GINI
# ..                           ...          ...            ...            ...
# 261                       Kosovo          XKX     Gini index    SI.POV.GINI
# 262                  Yemen, Rep.          YEM     Gini index    SI.POV.GINI
# 263                 South Africa          ZAF     Gini index    SI.POV.GINI
# 264                       Zambia          ZMB     Gini index    SI.POV.GINI
# 265                     Zimbabwe          ZWE     Gini index    SI.POV.GINI
#
#      1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  59.3   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN   NaN  60.5   NaN  52.6   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN  52.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN   NaN  29.0   NaN  31.2  30.3   NaN
# 262   NaN   NaN  35.0   NaN   NaN   NaN   NaN   NaN   NaN  34.7   NaN   NaN
# 263   NaN   NaN   NaN   NaN  57.8   NaN   NaN   NaN   NaN  64.8   NaN   NaN
# 264  48.3   NaN  49.1   NaN   NaN   NaN  42.1   NaN  54.3   NaN  54.6   NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    42.7   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  51.3   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN  31.8  33.3  27.8  29.0  26.3  27.3  26.5  26.7  29.0   NaN   NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN  36.7   NaN   NaN   NaN   NaN   NaN
# 263  63.0   NaN  63.4   NaN   NaN   NaN  63.0   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN  52.0   NaN   NaN   NaN   NaN  55.9   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN  43.2   NaN   NaN   NaN   NaN   NaN  44.3   NaN  50.3
#
#      2020  2021  2022  Unnamed: 67
# 0     NaN   NaN   NaN          NaN
# 1     NaN   NaN   NaN          NaN
# 2     NaN   NaN   NaN          NaN
# 3     NaN   NaN   NaN          NaN
# 4     NaN   NaN   NaN          NaN
# ..    ...   ...   ...          ...
# 261   NaN   NaN   NaN          NaN
# 262   NaN   NaN   NaN          NaN
# 263   NaN   NaN   NaN          NaN
# 264   NaN   NaN   NaN          NaN
# 265   NaN   NaN   NaN          NaN
#
# [266 rows x 68 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
gini_initial_data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              266
# 1961              266
# 1962              266
# 1963              265
# 1964              265
# 1965              265
# 1966              265
# 1967              265
# 1968              264
# 1969              264
# 1970              263
# 1971              263
# 1972              264
# 1973              263
# 1974              264
# 1975              261
# 1976              264
# 1977              262
# 1978              264
# 1979              259
# 1980              261
# 1981              257
# 1982              261
# 1983              260
# 1984              258
# 1985              252
# 1986              250
# 1987              244
# 1988              253
# 1989              250
# 1990              244
# 1991              247
# 1992              232
# 1993              240
# 1994              240
# 1995              228
# 1996              230
# 1997              236
# 1998              225
# 1999              229
# 2000              217
# 2001              228
# 2002              209
# 2003              206
# 2004              196
# 2005              190
# 2006              189
# 2007              196
# 2008              191
# 2009              187
# 2010              182
# 2011              187
# 2012              181
# 2013              189
# 2014              183
# 2015              181
# 2016              183
# 2017              190
# 2018              178
# 2019              195
# 2020              213
# 2021              244
# 2022              259
# Unnamed: 67       266
# dtype: int64

# %% [markdown]
# Seems to be a lot of data missing in this dataset, might not be able to use it quite as desired but will still reconstruct it and add it for the relevant years (i.e. 2010 onwards).

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

gini_unpivot_dataset = pd.melt(gini_initial_data, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                       var_name='Year', value_name='Value')

gini_unpivot_dataset
# Out:
#                       Country Name Country Code Indicator Name Indicator Code  \
# 0                            Aruba          ABW     Gini index    SI.POV.GINI
# 1      Africa Eastern and Southern          AFE     Gini index    SI.POV.GINI
# 2                      Afghanistan          AFG     Gini index    SI.POV.GINI
# 3       Africa Western and Central          AFW     Gini index    SI.POV.GINI
# 4                           Angola          AGO     Gini index    SI.POV.GINI
# ...                            ...          ...            ...            ...
# 17019                       Kosovo          XKX     Gini index    SI.POV.GINI
# 17020                  Yemen, Rep.          YEM     Gini index    SI.POV.GINI
# 17021                 South Africa          ZAF     Gini index    SI.POV.GINI
# 17022                       Zambia          ZMB     Gini index    SI.POV.GINI
# 17023                     Zimbabwe          ZWE     Gini index    SI.POV.GINI
#
#               Year  Value
# 0             1960    NaN
# 1             1960    NaN
# 2             1960    NaN
# 3             1960    NaN
# 4             1960    NaN
# ...            ...    ...
# 17019  Unnamed: 67    NaN
# 17020  Unnamed: 67    NaN
# 17021  Unnamed: 67    NaN
# 17022  Unnamed: 67    NaN
# 17023  Unnamed: 67    NaN
#
# [17024 rows x 6 columns]

# %%
gini_years_only = gini_unpivot_dataset[(gini_unpivot_dataset['Year'] != 'Unnamed: 67')]
gini_years_only
# Out:
#                       Country Name Country Code Indicator Name Indicator Code  \
# 0                            Aruba          ABW     Gini index    SI.POV.GINI
# 1      Africa Eastern and Southern          AFE     Gini index    SI.POV.GINI
# 2                      Afghanistan          AFG     Gini index    SI.POV.GINI
# 3       Africa Western and Central          AFW     Gini index    SI.POV.GINI
# 4                           Angola          AGO     Gini index    SI.POV.GINI
# ...                            ...          ...            ...            ...
# 16753                       Kosovo          XKX     Gini index    SI.POV.GINI
# 16754                  Yemen, Rep.          YEM     Gini index    SI.POV.GINI
# 16755                 South Africa          ZAF     Gini index    SI.POV.GINI
# 16756                       Zambia          ZMB     Gini index    SI.POV.GINI
# 16757                     Zimbabwe          ZWE     Gini index    SI.POV.GINI
#
#        Year  Value
# 0      1960    NaN
# 1      1960    NaN
# 2      1960    NaN
# 3      1960    NaN
# 4      1960    NaN
# ...     ...    ...
# 16753  2022    NaN
# 16754  2022    NaN
# 16755  2022    NaN
# 16756  2022    NaN
# 16757  2022    NaN
#
# [16758 rows x 6 columns]

# %% [markdown]
# Again chaging data type to integer and then filtering out years before 2010.

# %%
gini_years_only['Year'] = pd.to_numeric(gini_years_only['Year'], errors='coerce')
gini_years_only.dtypes
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/2558772313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gini_years_only['Year'] = pd.to_numeric(gini_years_only['Year'], errors='coerce')
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# Year                int64
# Value             float64
# dtype: object

# %%
gini_relevant_years = gini_years_only[(gini_years_only['Year'] >= 2010)]
gini_relevant_years
# Out:
#                       Country Name Country Code Indicator Name Indicator Code  \
# 13300                        Aruba          ABW     Gini index    SI.POV.GINI
# 13301  Africa Eastern and Southern          AFE     Gini index    SI.POV.GINI
# 13302                  Afghanistan          AFG     Gini index    SI.POV.GINI
# 13303   Africa Western and Central          AFW     Gini index    SI.POV.GINI
# 13304                       Angola          AGO     Gini index    SI.POV.GINI
# ...                            ...          ...            ...            ...
# 16753                       Kosovo          XKX     Gini index    SI.POV.GINI
# 16754                  Yemen, Rep.          YEM     Gini index    SI.POV.GINI
# 16755                 South Africa          ZAF     Gini index    SI.POV.GINI
# 16756                       Zambia          ZMB     Gini index    SI.POV.GINI
# 16757                     Zimbabwe          ZWE     Gini index    SI.POV.GINI
#
#        Year  Value
# 13300  2010    NaN
# 13301  2010    NaN
# 13302  2010    NaN
# 13303  2010    NaN
# 13304  2010    NaN
# ...     ...    ...
# 16753  2022    NaN
# 16754  2022    NaN
# 16755  2022    NaN
# 16756  2022    NaN
# 16757  2022    NaN
#
# [3458 rows x 6 columns]

# %%
merged2_df = pd.merge(internet_gni_df, gini_relevant_years[['Country Code', 'Year', 'Value']], how='outer', left_on=['ISO', 'Year'], right_on=['Country Code', 'Year'])
merged2_df = merged2_df.rename(columns={'Value': 'GINI Index'})
merged2_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 3469          NaN             NaN  NaN  2022
# 3470          NaN             NaN  NaN  2022
# 3471          NaN             NaN  NaN  2022
# 3472          NaN             NaN  NaN  2022
# 3473          NaN             NaN  NaN  2022
#
#       Individuals using the Internet, total (%) Country Code_x  \
# 0                                      4.000000            AFG
# 1                                      5.000000            AFG
# 2                                      5.454545            AFG
# 3                                      5.900000            AFG
# 4                                      7.000000            AFG
# ...                                         ...            ...
# 3469                                        NaN            NaN
# 3470                                        NaN            NaN
# 3471                                        NaN            NaN
# 3472                                        NaN            NaN
# 3473                                        NaN            NaN
#
#       GNI per capita Country Code_y  GINI Index
# 0              520.0            AFG         NaN
# 1              550.0            AFG         NaN
# 2              650.0            AFG         NaN
# 3              680.0            AFG         NaN
# 4              650.0            AFG         NaN
# ...              ...            ...         ...
# 3469             NaN            UMC         NaN
# 3470             NaN            VGB         NaN
# 3471             NaN            VIR         NaN
# 3472             NaN            WLD         NaN
# 3473             NaN            XKX         NaN
#
# [3474 rows x 9 columns]

# %% [markdown]
# Again checking and then removing aggregate results for regions etc.

# %%
codes_to_drop2 = []
country_codes2 = merged2_df['Country Code_y'].tolist()
iso_codes2 = merged2_df['ISO'].tolist()

for code in country_codes2:
    if code not in iso_codes2:
        codes_to_drop2.append(code)

country_code_country_dict2 = dict(zip(gini_relevant_years['Country Code'], gini_relevant_years['Country Name']))

filtered_dict2 = {key: value for key, value in country_code_country_dict2.items() if key in codes_to_drop2}
filtered_dict2
# Out:
# {'ABW': 'Aruba',
#  'AFE': 'Africa Eastern and Southern',
#  'AFW': 'Africa Western and Central',
#  'ARB': 'Arab World',
#  'ASM': 'American Samoa',
#  'BMU': 'Bermuda',
#  'CEB': 'Central Europe and the Baltics',
#  'CHI': 'Channel Islands',
#  'CSS': 'Caribbean small states',
#  'CUW': 'Curacao',
#  'CYM': 'Cayman Islands',
#  'EAP': 'East Asia & Pacific (excluding high income)',
#  'EAR': 'Early-demographic dividend',
#  'EAS': 'East Asia & Pacific',
#  'ECA': 'Europe & Central Asia (excluding high income)',
#  'ECS': 'Europe & Central Asia',
#  'EMU': 'Euro area',
#  'EUU': 'European Union',
#  'FCS': 'Fragile and conflict affected situations',
#  'FRO': 'Faroe Islands',
#  'GIB': 'Gibraltar',
#  'GRL': 'Greenland',
#  'GUM': 'Guam',
#  'HIC': 'High income',
#  'HPC': 'Heavily indebted poor countries (HIPC)',
#  'IBD': 'IBRD only',
#  'IBT': 'IDA & IBRD total',
#  'IDA': 'IDA total',
#  'IDB': 'IDA blend',
#  'IDX': 'IDA only',
#  'IMN': 'Isle of Man',
#  'INX': 'Not classified',
#  'LAC': 'Latin America & Caribbean (excluding high income)',
#  'LCN': 'Latin America & Caribbean',
#  'LDC': 'Least developed countries: UN classification',
#  'LIC': 'Low income',
#  'LMC': 'Lower middle income',
#  'LMY': 'Low & middle income',
#  'LTE': 'Late-demographic dividend',
#  'MAF': 'St. Martin (French part)',
#  'MEA': 'Middle East & North Africa',
#  'MIC': 'Middle income',
#  'MNA': 'Middle East & North Africa (excluding high income)',
#  'MNP': 'Northern Mariana Islands',
#  'NAC': 'North America',
#  'NCL': 'New Caledonia',
#  'OED': 'OECD members',
#  'OSS': 'Other small states',
#  'PLW': 'Palau',
#  'PRE': 'Pre-demographic dividend',
#  'PRI': 'Puerto Rico',
#  'PSE': 'West Bank and Gaza',
#  'PSS': 'Pacific island small states',
#  'PST': 'Post-demographic dividend',
#  'PYF': 'French Polynesia',
#  'SAS': 'South Asia',
#  'SSA': 'Sub-Saharan Africa (excluding high income)',
#  'SSF': 'Sub-Saharan Africa',
#  'SST': 'Small states',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'TCA': 'Turks and Caicos Islands',
#  'TEA': 'East Asia & Pacific (IDA & IBRD countries)',
#  'TEC': 'Europe & Central Asia (IDA & IBRD countries)',
#  'TLA': 'Latin America & the Caribbean (IDA & IBRD countries)',
#  'TMN': 'Middle East & North Africa (IDA & IBRD countries)',
#  'TSA': 'South Asia (IDA & IBRD)',
#  'TSS': 'Sub-Saharan Africa (IDA & IBRD countries)',
#  'UMC': 'Upper middle income',
#  'VGB': 'British Virgin Islands',
#  'VIR': 'Virgin Islands (U.S.)',
#  'WLD': 'World',
#  'XKX': 'Kosovo'}

# %%
internet_gni_gini_df = merged2_df[~merged2_df['Country Code_y'].isin(codes_to_drop2)]
internet_gni_gini_df
# Out:
#                           Country          Region  ISO  Year  \
# 0                     Afghanistan  Asia & Pacific  AFG  2010
# 1                     Afghanistan  Asia & Pacific  AFG  2011
# 2                     Afghanistan  Asia & Pacific  AFG  2012
# 3                     Afghanistan  Asia & Pacific  AFG  2013
# 4                     Afghanistan  Asia & Pacific  AFG  2014
# ...                           ...             ...  ...   ...
# 2533                     Zimbabwe          Africa  ZWE  2020
# 2534                     Zimbabwe          Africa  ZWE  2021
# 2535                     Zimbabwe          Africa  ZWE  2022
# 2536                      Eritrea          Africa  ERI  2018
# 2537  Dem. People's Rep. of Korea  Asia & Pacific  PRK  2018
#
#       Individuals using the Internet, total (%) Country Code_x  \
# 0                                      4.000000            AFG
# 1                                      5.000000            AFG
# 2                                      5.454545            AFG
# 3                                      5.900000            AFG
# 4                                      7.000000            AFG
# ...                                         ...            ...
# 2533                                  29.298565            ZWE
# 2534                                  34.813971            ZWE
# 2535                                        NaN            ZWE
# 2536                                        NaN            ERI
# 2537                                        NaN            PRK
#
#       GNI per capita Country Code_y  GINI Index
# 0              520.0            AFG         NaN
# 1              550.0            AFG         NaN
# 2              650.0            AFG         NaN
# 3              680.0            AFG         NaN
# 4              650.0            AFG         NaN
# ...              ...            ...         ...
# 2533          1460.0            ZWE         NaN
# 2534          1530.0            ZWE         NaN
# 2535          1500.0            ZWE         NaN
# 2536             NaN            ERI         NaN
# 2537             NaN            PRK         NaN
#
# [2538 rows x 9 columns]

# %%
columns_to_drop = ['Country Code_x', 'Country Code_y']
internet_gni_gini_df.drop(columns=columns_to_drop, inplace=True, axis=1)
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/2539365989.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet_gni_gini_df.drop(columns=columns_to_drop, inplace=True, axis=1)

# %%
internet_gni_gini_df.shape
# Out:
# (2538, 7)

# %% [markdown]
# At the end of this section the dataset is called internet_gni_gini_df

# %% [markdown]
# ## GDP Data Cleaning <a name="gdpcleaning"></a>
# Pulling in and setting up the data from the world bank dataset on GDP by country by year.

# %%
gdp_initial_data = pd.read_csv("data/API_NY.GDP.PCAP.CD_DS2_en_csv_v2_5994720.csv", skiprows=4)
gdp_initial_data
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
#      Indicator Code        1960        1961        1962        1963  \
# 0    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 1    NY.GDP.PCAP.CD  161.638982  161.111657  170.538537  198.038919
# 2    NY.GDP.PCAP.CD   62.369375   62.443703   60.950364   82.021738
# 3    NY.GDP.PCAP.CD  107.423775  112.503866  118.197351  122.774120
# 4    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# ..              ...         ...         ...         ...         ...
# 261  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 262  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 263  NY.GDP.PCAP.CD  529.561923  543.042224  560.699395  601.599951
# 264  NY.GDP.PCAP.CD  228.567399  216.274674  208.562685  209.453362
# 265  NY.GDP.PCAP.CD  276.643363  279.332656  275.966139  277.532515
#
#            1964        1965        1966        1967        1968        1969  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1    178.019217  196.818756  207.945574  210.149894  223.040659  248.448220
# 2     85.511073  105.243196  143.103233  167.165675  134.012768  134.250360
# 3    131.163760  137.809818  143.601581  128.049650  129.123648  143.145552
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 261         NaN         NaN         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN         NaN         NaN
# 263  642.688431  681.131112  718.118179  775.152812  813.508497  887.246703
# 264  236.941713  296.022427  334.672528  350.653425  398.557506  472.640293
# 265  282.376856  294.893605  279.337779  295.056449  302.802871  346.538920
#
#            1970         1971         1972         1973         1974  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1    258.760362   277.028107   290.929486   369.782388   441.214102
# 2    162.642175   166.224831   141.365322   149.744068   181.598776
# 3    194.327390   168.385279   199.319750   244.905282   331.581835
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 261         NaN          NaN          NaN          NaN          NaN
# 262         NaN          NaN          NaN          NaN          NaN
# 263  948.591794  1016.483483  1034.491821  1364.205868  1650.482891
# 264  426.302188   383.416149   413.923544   523.125737   607.842590
# 265  362.144147   406.217503   483.969974   579.296418   674.539030
#
#             1975         1976         1977         1978         1979  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1     455.808233   439.627553   484.274983   533.768074   598.516558
# 2     194.669036   205.674097   232.778699   255.045622   284.755532
# 3     375.628580   441.401165   451.997204   479.177640   579.620309
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 261          NaN          NaN          NaN          NaN          NaN
# 262          NaN          NaN          NaN          NaN          NaN
# 263  1664.480557  1554.002408  1666.495218  1846.851738  2196.698510
# 264   495.345528   539.967790   480.633785   521.396286   603.847722
# 265   716.949515   686.721730   676.329202   664.432526   777.883009
#
#             1980         1981         1982         1983         1984  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1     741.305705   739.098653   685.023457   694.537147   617.375482
# 2     291.649791   311.853617          NaN          NaN          NaN
# 3     712.426374  1301.957532  1122.290300   806.591433   650.459671
# 4     711.941169   643.052851   620.363110   623.533933   637.519759
# ..           ...          ...          ...          ...          ...
# 261          NaN          NaN          NaN          NaN          NaN
# 262          NaN          NaN          NaN          NaN          NaN
# 263  3034.661390  3080.833219  2769.096638  3019.098685  2590.014602
# 264   679.061788   679.633643   635.566043   527.898823   419.156713
# 265   947.367135  1067.254520  1094.292590   957.775232   756.334491
#
#             1985         1986         1987         1988          1989  \
# 0            NaN  6283.001443  7567.253642  9274.514156  10767.396220
# 1     510.414257   554.458043   656.115225   699.348882    724.754485
# 2            NaN          NaN          NaN          NaN           NaN
# 3     645.828620   580.908731   580.461595   558.447755    507.740610
# 4     757.632389   684.489277   755.972445   792.914088    891.803205
# ..           ...          ...          ...          ...           ...
# 261          NaN          NaN          NaN          NaN           NaN
# 262          NaN          NaN          NaN          NaN           NaN
# 263  1909.739723  2103.192019  2672.689100  2780.586818   2794.395679
# 264   336.868568   241.535551   319.265949   511.202633    533.243428
# 265   648.668036   692.139958   726.620730   816.699473    841.563226
#
#              1990          1991          1992          1993          1994  \
# 0    11638.733706  12850.215712  13657.670644  14970.152342  16675.278488
# 1      819.844296    869.131599    752.716098    723.802778    695.696584
# 2             NaN           NaN           NaN           NaN           NaN
# 3      591.989608    556.337330    545.465986    443.597693    377.211747
# 4      949.349841   1038.914019   1196.464962    847.653799    251.856499
# ..            ...           ...           ...           ...           ...
# 261           NaN           NaN           NaN           NaN           NaN
# 262    422.210702    426.772737    447.814364    358.170121    267.942533
# 263   3160.878365   3304.828377   3519.001091   3461.334353   3547.951415
# 264    427.406453    428.503428    394.078398    395.785347    431.521716
# 265    868.490175    832.687969    634.447359    608.046610    634.582617
#
#              1995          1996          1997          1998          1999  \
# 0    17140.433369  17375.225306  18713.425388  19742.316739  19833.826746
# 1      764.788395    742.428029    761.231441    698.562841    671.862171
# 2             NaN           NaN           NaN           NaN           NaN
# 3      460.825071    521.416803    513.050543    511.494584    526.248227
# 4      399.735558    523.310909    514.309887    423.393453    387.689415
# ..            ...           ...           ...           ...           ...
# 261           NaN           NaN           NaN           NaN           NaN
# 262    264.466191    348.234729    399.712718    359.217055    421.821225
# 263   3904.324238   3654.927456   3731.431830   3336.439547   3267.939079
# 264    438.383636    404.090461    471.172300    377.462582    353.830209
# 265    646.829560    765.165124    750.683909    554.361484    585.331799
#
#              2000          2001          2002          2003          2004  \
# 0    21023.157513  20913.299497  21377.095185  22050.830932  24104.646177
# 1      709.061010    630.198869    630.479082    816.437662    989.220845
# 2             NaN           NaN    183.532775    200.462376    221.657662
# 3      522.772772    535.897917    621.862505    700.443384    843.989814
# 4      556.884244    527.464118    872.657638    982.805590   1254.696126
# ..            ...           ...           ...           ...           ...
# 261           NaN           NaN           NaN           NaN           NaN
# 262    518.148673    515.139982    543.960981    583.391150    669.103362
# 263   3241.661240   2867.472552   2708.423419   4095.683610   5268.278984
# 264    364.026126    401.732316    399.099078    452.286578    556.050007
# 265    565.284390    569.003209    529.186883    474.302201    477.399491
#
#              2005          2006          2007          2008          2009  \
# 0    24975.673257  25833.445623  27665.426465  29011.559245  25739.137251
# 1     1124.220303   1230.194793   1374.086248   1433.258304   1417.130587
# 2      255.055107    274.000656    375.078261    387.849288    443.845151
# 3     1003.436618   1245.822948   1420.840336   1685.371170   1467.241236
# 4     1900.723817   2597.963585   3121.348735   4081.717497   3123.698898
# ..            ...           ...           ...           ...           ...
# 261           NaN           NaN           NaN   2965.449915   2847.555339
# 262    785.451250    867.782937    956.230635   1153.536424   1045.805580
# 263   5893.186767   6139.581467   6662.062785   6251.877175   6444.186720
# 264    720.446505   1065.596417   1133.436158   1393.519491   1150.941746
# 265    470.783761    441.498797    425.036842    351.839101    762.297960
#
#              2010          2011          2012          2013          2014  \
# 0    24452.928363  26044.435933  25609.955724  26515.678080  26942.307976
# 1     1649.639146   1799.623009   1765.250073   1736.222507   1724.534381
# 2      554.594735    621.912414    663.141053    651.987862    628.146804
# 3     1679.646727   1860.943928   1957.519614   2153.766138   2247.857492
# 4     3496.784796   4511.153227   4962.552072   5101.983876   5059.080441
# ..            ...           ...           ...           ...           ...
# 261   3009.523465   3540.823286   3410.692727   3704.562199   3902.529820
# 262   1249.063085   1284.617635   1349.990295   1497.747941   1557.601406
# 263   8059.562841   8737.041110   8173.869138   7441.230854   6965.137897
# 264   1469.361450   1644.456831   1729.647471   1840.320553   1724.576220
# 265    937.840340   1082.615773   1290.193957   1408.367810   1407.034291
#
#              2015          2016          2017          2018          2019  \
# 0    28421.386493  28451.273745  29326.708058  30918.515218  31902.762582
# 1     1545.559084   1436.094404   1613.668488   1550.111762   1499.954437
# 2      592.476165    520.251955    530.149863    502.057099    500.522981
# 3     1880.750778   1646.972399   1588.581005   1732.816544   1810.538006
# 4     3100.830685   1709.515534   2283.214233   2487.500996   2142.238757
# ..            ...           ...           ...           ...           ...
# 261   3520.780421   3759.471040   4009.356038   4384.190404   4416.031322
# 262   1488.416267   1069.816997    893.716573    701.714878    693.816484
# 263   6204.929901   5735.066787   6734.475153   7048.508112   6688.774746
# 264   1307.909649   1249.923143   1495.752138   1475.199836   1268.120941
# 265   1410.329173   1421.787791   1192.107012   2269.177012   1421.868596
#
#              2020          2021         2022  Unnamed: 67
# 0    24487.863569  29342.100730          NaN          NaN
# 1     1353.927527   1539.165543  1622.391720          NaN
# 2      516.866797    363.674087          NaN          NaN
# 3     1686.997899   1765.965307  1790.348800          NaN
# 4     1502.950754   1903.717405  2998.501158          NaN
# ..            ...           ...          ...          ...
# 261   4310.932984   5269.783901  5351.439542          NaN
# 262    583.875663    603.707959   676.928385          NaN
# 263   5741.641249   7055.055176  6776.480077          NaN
# 264    956.831747   1137.344395  1487.907764          NaN
# 265   1372.696674   1773.920411  1266.996031          NaN
#
# [266 rows x 68 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
gdp_initial_data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              134
# 1961              132
# 1962              130
# 1963              130
# 1964              130
# 1965              119
# 1966              116
# 1967              113
# 1968              108
# 1969              108
# 1970               99
# 1971               96
# 1972               96
# 1973               96
# 1974               95
# 1975               93
# 1976               92
# 1977               89
# 1978               90
# 1979               89
# 1980               75
# 1981               72
# 1982               71
# 1983               70
# 1984               69
# 1985               67
# 1986               65
# 1987               61
# 1988               56
# 1989               56
# 1990               40
# 1991               40
# 1992               39
# 1993               37
# 1994               35
# 1995               26
# 1996               26
# 1997               26
# 1998               24
# 1999               23
# 2000               19
# 2001               17
# 2002               12
# 2003               12
# 2004               12
# 2005               12
# 2006               11
# 2007               11
# 2008               10
# 2009               10
# 2010                9
# 2011                6
# 2012                8
# 2013                7
# 2014                6
# 2015                8
# 2016                8
# 2017                8
# 2018                8
# 2019                8
# 2020                8
# 2021               14
# 2022               32
# Unnamed: 67       266
# dtype: int64

# %%
pd.set_option('display.max_rows', 10)

gdp_unpivot_dataset = pd.melt(gdp_initial_data, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                       var_name='Year', value_name='Value')

gdp_unpivot_dataset
# Out:
#                       Country Name Country Code                Indicator Name  \
# 0                            Aruba          ABW  GDP per capita (current US$)
# 1      Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                      Afghanistan          AFG  GDP per capita (current US$)
# 3       Africa Western and Central          AFW  GDP per capita (current US$)
# 4                           Angola          AGO  GDP per capita (current US$)
# ...                            ...          ...                           ...
# 17019                       Kosovo          XKX  GDP per capita (current US$)
# 17020                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 17021                 South Africa          ZAF  GDP per capita (current US$)
# 17022                       Zambia          ZMB  GDP per capita (current US$)
# 17023                     Zimbabwe          ZWE  GDP per capita (current US$)
#
#        Indicator Code         Year       Value
# 0      NY.GDP.PCAP.CD         1960         NaN
# 1      NY.GDP.PCAP.CD         1960  161.638982
# 2      NY.GDP.PCAP.CD         1960   62.369375
# 3      NY.GDP.PCAP.CD         1960  107.423775
# 4      NY.GDP.PCAP.CD         1960         NaN
# ...               ...          ...         ...
# 17019  NY.GDP.PCAP.CD  Unnamed: 67         NaN
# 17020  NY.GDP.PCAP.CD  Unnamed: 67         NaN
# 17021  NY.GDP.PCAP.CD  Unnamed: 67         NaN
# 17022  NY.GDP.PCAP.CD  Unnamed: 67         NaN
# 17023  NY.GDP.PCAP.CD  Unnamed: 67         NaN
#
# [17024 rows x 6 columns]

# %%
gdp_years_only = gdp_unpivot_dataset[(gini_unpivot_dataset['Year'] != 'Unnamed: 67')]

gdp_years_only.loc[:, 'Year'] = gdp_years_only['Year'].astype(int)

gdp_relevant_years = gdp_years_only[(gdp_years_only['Year'] >= 2010)]
gdp_relevant_years
# Out:
#                       Country Name Country Code                Indicator Name  \
# 13300                        Aruba          ABW  GDP per capita (current US$)
# 13301  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 13302                  Afghanistan          AFG  GDP per capita (current US$)
# 13303   Africa Western and Central          AFW  GDP per capita (current US$)
# 13304                       Angola          AGO  GDP per capita (current US$)
# ...                            ...          ...                           ...
# 16753                       Kosovo          XKX  GDP per capita (current US$)
# 16754                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 16755                 South Africa          ZAF  GDP per capita (current US$)
# 16756                       Zambia          ZMB  GDP per capita (current US$)
# 16757                     Zimbabwe          ZWE  GDP per capita (current US$)
#
#        Indicator Code  Year         Value
# 13300  NY.GDP.PCAP.CD  2010  24452.928363
# 13301  NY.GDP.PCAP.CD  2010   1649.639146
# 13302  NY.GDP.PCAP.CD  2010    554.594735
# 13303  NY.GDP.PCAP.CD  2010   1679.646727
# 13304  NY.GDP.PCAP.CD  2010   3496.784796
# ...               ...   ...           ...
# 16753  NY.GDP.PCAP.CD  2022   5351.439542
# 16754  NY.GDP.PCAP.CD  2022    676.928385
# 16755  NY.GDP.PCAP.CD  2022   6776.480077
# 16756  NY.GDP.PCAP.CD  2022   1487.907764
# 16757  NY.GDP.PCAP.CD  2022   1266.996031
#
# [3458 rows x 6 columns]

# %%
merged3_df = pd.merge(internet_gni_gini_df, gdp_relevant_years[['Country Code', 'Year', 'Value']], how='outer', left_on=['ISO', 'Year'], right_on=['Country Code', 'Year'])
merged3_df = merged3_df.rename(columns={'Value': 'GDP Per Capita'})
merged3_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 3469          NaN             NaN  NaN  2022
# 3470          NaN             NaN  NaN  2022
# 3471          NaN             NaN  NaN  2022
# 3472          NaN             NaN  NaN  2022
# 3473          NaN             NaN  NaN  2022
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 3469                                        NaN             NaN         NaN
# 3470                                        NaN             NaN         NaN
# 3471                                        NaN             NaN         NaN
# 3472                                        NaN             NaN         NaN
# 3473                                        NaN             NaN         NaN
#
#      Country Code  GDP Per Capita
# 0             AFG      554.594735
# 1             AFG      621.912414
# 2             AFG      663.141053
# 3             AFG      651.987862
# 4             AFG      628.146804
# ...           ...             ...
# 3469          UMC    10794.931857
# 3470          VGB             NaN
# 3471          VIR             NaN
# 3472          WLD    12647.480789
# 3473          XKX     5351.439542
#
# [3474 rows x 9 columns]

# %%
codes_to_drop3 = []
country_codes3 = merged3_df['Country Code'].tolist()
iso_codes3 = merged3_df['ISO'].tolist()

for code in country_codes3:
    if code not in iso_codes3:
        codes_to_drop3.append(code)

country_code_country_dict3 = dict(zip(gdp_relevant_years['Country Code'], gdp_relevant_years['Country Name']))

filtered_dict3 = {key: value for key, value in country_code_country_dict3.items() if key in codes_to_drop3}
filtered_dict3
# Out:
# {'ABW': 'Aruba',
#  'AFE': 'Africa Eastern and Southern',
#  'AFW': 'Africa Western and Central',
#  'ARB': 'Arab World',
#  'ASM': 'American Samoa',
#  'BMU': 'Bermuda',
#  'CEB': 'Central Europe and the Baltics',
#  'CHI': 'Channel Islands',
#  'CSS': 'Caribbean small states',
#  'CUW': 'Curacao',
#  'CYM': 'Cayman Islands',
#  'EAP': 'East Asia & Pacific (excluding high income)',
#  'EAR': 'Early-demographic dividend',
#  'EAS': 'East Asia & Pacific',
#  'ECA': 'Europe & Central Asia (excluding high income)',
#  'ECS': 'Europe & Central Asia',
#  'EMU': 'Euro area',
#  'EUU': 'European Union',
#  'FCS': 'Fragile and conflict affected situations',
#  'FRO': 'Faroe Islands',
#  'GIB': 'Gibraltar',
#  'GRL': 'Greenland',
#  'GUM': 'Guam',
#  'HIC': 'High income',
#  'HPC': 'Heavily indebted poor countries (HIPC)',
#  'IBD': 'IBRD only',
#  'IBT': 'IDA & IBRD total',
#  'IDA': 'IDA total',
#  'IDB': 'IDA blend',
#  'IDX': 'IDA only',
#  'IMN': 'Isle of Man',
#  'INX': 'Not classified',
#  'LAC': 'Latin America & Caribbean (excluding high income)',
#  'LCN': 'Latin America & Caribbean',
#  'LDC': 'Least developed countries: UN classification',
#  'LIC': 'Low income',
#  'LMC': 'Lower middle income',
#  'LMY': 'Low & middle income',
#  'LTE': 'Late-demographic dividend',
#  'MAF': 'St. Martin (French part)',
#  'MEA': 'Middle East & North Africa',
#  'MIC': 'Middle income',
#  'MNA': 'Middle East & North Africa (excluding high income)',
#  'MNP': 'Northern Mariana Islands',
#  'NAC': 'North America',
#  'NCL': 'New Caledonia',
#  'OED': 'OECD members',
#  'OSS': 'Other small states',
#  'PLW': 'Palau',
#  'PRE': 'Pre-demographic dividend',
#  'PRI': 'Puerto Rico',
#  'PSE': 'West Bank and Gaza',
#  'PSS': 'Pacific island small states',
#  'PST': 'Post-demographic dividend',
#  'PYF': 'French Polynesia',
#  'SAS': 'South Asia',
#  'SSA': 'Sub-Saharan Africa (excluding high income)',
#  'SSF': 'Sub-Saharan Africa',
#  'SST': 'Small states',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'TCA': 'Turks and Caicos Islands',
#  'TEA': 'East Asia & Pacific (IDA & IBRD countries)',
#  'TEC': 'Europe & Central Asia (IDA & IBRD countries)',
#  'TLA': 'Latin America & the Caribbean (IDA & IBRD countries)',
#  'TMN': 'Middle East & North Africa (IDA & IBRD countries)',
#  'TSA': 'South Asia (IDA & IBRD)',
#  'TSS': 'Sub-Saharan Africa (IDA & IBRD countries)',
#  'UMC': 'Upper middle income',
#  'VGB': 'British Virgin Islands',
#  'VIR': 'Virgin Islands (U.S.)',
#  'WLD': 'World',
#  'XKX': 'Kosovo'}

# %%
internet_gni_gini_gdp_df = merged3_df[~merged3_df['Country Code'].isin(codes_to_drop3)]
internet_gni_gini_gdp_df
# Out:
#                           Country          Region  ISO  Year  \
# 0                     Afghanistan  Asia & Pacific  AFG  2010
# 1                     Afghanistan  Asia & Pacific  AFG  2011
# 2                     Afghanistan  Asia & Pacific  AFG  2012
# 3                     Afghanistan  Asia & Pacific  AFG  2013
# 4                     Afghanistan  Asia & Pacific  AFG  2014
# ...                           ...             ...  ...   ...
# 2533                     Zimbabwe          Africa  ZWE  2020
# 2534                     Zimbabwe          Africa  ZWE  2021
# 2535                     Zimbabwe          Africa  ZWE  2022
# 2536                      Eritrea          Africa  ERI  2018
# 2537  Dem. People's Rep. of Korea  Asia & Pacific  PRK  2018
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2533                                  29.298565          1460.0         NaN
# 2534                                  34.813971          1530.0         NaN
# 2535                                        NaN          1500.0         NaN
# 2536                                        NaN             NaN         NaN
# 2537                                        NaN             NaN         NaN
#
#      Country Code  GDP Per Capita
# 0             AFG      554.594735
# 1             AFG      621.912414
# 2             AFG      663.141053
# 3             AFG      651.987862
# 4             AFG      628.146804
# ...           ...             ...
# 2533          ZWE     1372.696674
# 2534          ZWE     1773.920411
# 2535          ZWE     1266.996031
# 2536          ERI             NaN
# 2537          PRK             NaN
#
# [2538 rows x 9 columns]

# %%
internet_gni_gini_gdp_df.drop(columns=['Country Code'], axis=1, inplace=True)
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3464669002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet_gni_gini_gdp_df.drop(columns=['Country Code'], axis=1, inplace=True)

# %%
internet_gni_gini_gdp_df.shape
# Out:
# (2538, 8)

# %% [markdown]
# Final dataset after this section is called: internet_gni_gini_gdp_df

# %% [markdown]
# ## Happiness Index Cleaning <a name="happinesindexcleaning"></a>
# Pulling in and setting up the data on the Happiness Index by country by year.

# %%
happiness_index = pd.read_csv("data/World Happiness Index by Reports 2013-2023 no nulls.csv")
happiness_index
# Out:
#           Country  Year  Index  Rank
# 0     Afghanistan  2013  4.040   143
# 1     Afghanistan  2015  3.575   153
# 2     Afghanistan  2016  3.360   154
# 3     Afghanistan  2017  3.794   141
# 4     Afghanistan  2018  3.632   145
# ...           ...   ...    ...   ...
# 1518     Zimbabwe  2019  3.663   146
# 1519     Zimbabwe  2020  3.299   151
# 1520     Zimbabwe  2021  3.145   148
# 1521     Zimbabwe  2022  2.995   144
# 1522     Zimbabwe  2023  3.204   134
#
# [1523 rows x 4 columns]

# %% [markdown]
# This dataset doesn't use ISO codes which will cause problems if there are different spellings. I found some datasets on github which try to solve this issue but linking different spellings to the world bank spelling and hence the ISO code, will use that to add an ISO column to the initial dataset.

# %%
pd.set_option('display.max_rows', 10)
country_names = pd.read_csv("data/any_name_to_wb_name.csv")
iso_codes = pd.read_csv("data/iso3_to_wb_name.csv")
country_names
# Out:
#                                   any      wb_name
# 0                         Afghanistan  Afghanistan
# 1    Afghanistan, islamic republic of  Afghanistan
# 2                       Aland Islands          NaN
# 3                               Aland          NaN
# 4                             Albania      Albania
# ..                                ...          ...
# 406                             Yemen  Yemen, Rep.
# 407                Yemen, republic of  Yemen, Rep.
# 408                       Yemen, Rep.  Yemen, Rep.
# 409                            Zambia       Zambia
# 410                          Zimbabwe     Zimbabwe
#
# [411 rows x 2 columns]

# %%
hap_merge_names = pd.merge(happiness_index, country_names, how="left", left_on="Country", right_on="any")
list_missing = hap_merge_names[hap_merge_names["wb_name"].isnull()]
countries = list_missing["Country"].unique()
countries
# Out:
# array(['Congo Brazzaville', 'Congo Kinshasa', 'Czechia', 'Eswatini',
#        'North Cyprus', 'North Macedonia', 'Palestine', 'Somaliland',
#        'Turkiye'], dtype=object)

# %% [markdown]
# Some of these I can just add to the csv with the spelling / name the world bank references and others are contested territories which won't appear in the other datasets so I will just drop before the merger

# %%
new_rows = [
    {'any': 'Congo Brazzaville', 'wb_name': "Congo, Rep."},
    {'any': 'Congo Kinshasa', 'wb_name': "Congo, Dem. Rep."},
    {'any': 'Czechia', 'wb_name': "Czech Republic"},
    {'any': 'Eswatini', 'wb_name': "Swaziland"},
    {'any': 'North Macedonia', 'wb_name': "Macedonia, FYR"},
    {'any': 'Palestine', 'wb_name': "West Bank and Gaza"},
    {'any': 'Turkiye', 'wb_name': "Turkey"}
]

new_rows_df = pd.DataFrame(new_rows)

country_names = pd.concat([country_names, new_rows_df], ignore_index=True)

# %% [markdown]
# Now rerunning the merger and checking empty rows

# %%
hap_merge_names = pd.merge(happiness_index, country_names, how="left", left_on="Country", right_on="any")
list_missing = hap_merge_names[hap_merge_names["wb_name"].isnull()]
countries = list_missing["Country"].unique()
countries
# Out:
# array(['North Cyprus', 'Somaliland'], dtype=object)

# %%
hap_merge_names = hap_merge_names[(hap_merge_names['Country'] != 'North Cyprus') & (hap_merge_names['Country'] != 'Somaliland')]

# %%
hap_merge_names
# Out:
#           Country  Year  Index  Rank          any      wb_name
# 0     Afghanistan  2013  4.040   143  Afghanistan  Afghanistan
# 1     Afghanistan  2015  3.575   153  Afghanistan  Afghanistan
# 2     Afghanistan  2016  3.360   154  Afghanistan  Afghanistan
# 3     Afghanistan  2017  3.794   141  Afghanistan  Afghanistan
# 4     Afghanistan  2018  3.632   145  Afghanistan  Afghanistan
# ...           ...   ...    ...   ...          ...          ...
# 1518     Zimbabwe  2019  3.663   146     Zimbabwe     Zimbabwe
# 1519     Zimbabwe  2020  3.299   151     Zimbabwe     Zimbabwe
# 1520     Zimbabwe  2021  3.145   148     Zimbabwe     Zimbabwe
# 1521     Zimbabwe  2022  2.995   144     Zimbabwe     Zimbabwe
# 1522     Zimbabwe  2023  3.204   134     Zimbabwe     Zimbabwe
#
# [1511 rows x 6 columns]

# %%
iso_codes.rename(columns={'country': 'Country WB Name'}, inplace=True)
iso_codes
# Out:
#     iso3 Country WB Name
# 0    ABW           Aruba
# 1    AFG     Afghanistan
# 2    AGO          Angola
# 3    AIA        Anguilla
# 4    ALB         Albania
# ..   ...             ...
# 216  WSM           Samoa
# 217  YEM     Yemen, Rep.
# 218  ZAF    South Africa
# 219  ZMB          Zambia
# 220  ZWE        Zimbabwe
#
# [221 rows x 2 columns]

# %%
hap_merge_iso = pd.merge(hap_merge_names, iso_codes, how="left", left_on="wb_name", right_on="Country WB Name")
hap_merge_iso
# Out:
#           Country  Year  Index  Rank          any      wb_name iso3  \
# 0     Afghanistan  2013  4.040   143  Afghanistan  Afghanistan  AFG
# 1     Afghanistan  2015  3.575   153  Afghanistan  Afghanistan  AFG
# 2     Afghanistan  2016  3.360   154  Afghanistan  Afghanistan  AFG
# 3     Afghanistan  2017  3.794   141  Afghanistan  Afghanistan  AFG
# 4     Afghanistan  2018  3.632   145  Afghanistan  Afghanistan  AFG
# ...           ...   ...    ...   ...          ...          ...  ...
# 1526     Zimbabwe  2019  3.663   146     Zimbabwe     Zimbabwe  ZWE
# 1527     Zimbabwe  2020  3.299   151     Zimbabwe     Zimbabwe  ZWE
# 1528     Zimbabwe  2021  3.145   148     Zimbabwe     Zimbabwe  ZWE
# 1529     Zimbabwe  2022  2.995   144     Zimbabwe     Zimbabwe  ZWE
# 1530     Zimbabwe  2023  3.204   134     Zimbabwe     Zimbabwe  ZWE
#
#      Country WB Name
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# ...              ...
# 1526        Zimbabwe
# 1527        Zimbabwe
# 1528        Zimbabwe
# 1529        Zimbabwe
# 1530        Zimbabwe
#
# [1531 rows x 8 columns]

# %%
hap_merge_iso.drop_duplicates(subset=['Country', 'Year', 'Index'], inplace=True)
hap_merge_iso
# Out:
#           Country  Year  Index  Rank          any      wb_name iso3  \
# 0     Afghanistan  2013  4.040   143  Afghanistan  Afghanistan  AFG
# 1     Afghanistan  2015  3.575   153  Afghanistan  Afghanistan  AFG
# 2     Afghanistan  2016  3.360   154  Afghanistan  Afghanistan  AFG
# 3     Afghanistan  2017  3.794   141  Afghanistan  Afghanistan  AFG
# 4     Afghanistan  2018  3.632   145  Afghanistan  Afghanistan  AFG
# ...           ...   ...    ...   ...          ...          ...  ...
# 1526     Zimbabwe  2019  3.663   146     Zimbabwe     Zimbabwe  ZWE
# 1527     Zimbabwe  2020  3.299   151     Zimbabwe     Zimbabwe  ZWE
# 1528     Zimbabwe  2021  3.145   148     Zimbabwe     Zimbabwe  ZWE
# 1529     Zimbabwe  2022  2.995   144     Zimbabwe     Zimbabwe  ZWE
# 1530     Zimbabwe  2023  3.204   134     Zimbabwe     Zimbabwe  ZWE
#
#      Country WB Name
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# ...              ...
# 1526        Zimbabwe
# 1527        Zimbabwe
# 1528        Zimbabwe
# 1529        Zimbabwe
# 1530        Zimbabwe
#
# [1511 rows x 8 columns]

# %%
hap_merge_iso.rename(columns={'iso3': 'ISO'}, inplace=True)
hap_merge_iso
# Out:
#           Country  Year  Index  Rank          any      wb_name  ISO  \
# 0     Afghanistan  2013  4.040   143  Afghanistan  Afghanistan  AFG
# 1     Afghanistan  2015  3.575   153  Afghanistan  Afghanistan  AFG
# 2     Afghanistan  2016  3.360   154  Afghanistan  Afghanistan  AFG
# 3     Afghanistan  2017  3.794   141  Afghanistan  Afghanistan  AFG
# 4     Afghanistan  2018  3.632   145  Afghanistan  Afghanistan  AFG
# ...           ...   ...    ...   ...          ...          ...  ...
# 1526     Zimbabwe  2019  3.663   146     Zimbabwe     Zimbabwe  ZWE
# 1527     Zimbabwe  2020  3.299   151     Zimbabwe     Zimbabwe  ZWE
# 1528     Zimbabwe  2021  3.145   148     Zimbabwe     Zimbabwe  ZWE
# 1529     Zimbabwe  2022  2.995   144     Zimbabwe     Zimbabwe  ZWE
# 1530     Zimbabwe  2023  3.204   134     Zimbabwe     Zimbabwe  ZWE
#
#      Country WB Name
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# ...              ...
# 1526        Zimbabwe
# 1527        Zimbabwe
# 1528        Zimbabwe
# 1529        Zimbabwe
# 1530        Zimbabwe
#
# [1511 rows x 8 columns]

# %%
merged4_df = pd.merge(internet_gni_gini_gdp_df, hap_merge_iso[["Index", "ISO", "Year", "Country"]], how='outer', left_on=['ISO', 'Year'], right_on=['ISO', 'Year'])
merged4_df = merged4_df.rename(columns={'Index': 'Happiness Index'})
merged4_df
# Out:
#         Country_x          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2698          NaN             NaN  UZB  2023
# 2699          NaN             NaN  VEN  2023
# 2700          NaN             NaN  VNM  2023
# 2701          NaN             NaN  ZMB  2023
# 2702          NaN             NaN  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2698                                        NaN             NaN         NaN
# 2699                                        NaN             NaN         NaN
# 2700                                        NaN             NaN         NaN
# 2701                                        NaN             NaN         NaN
# 2702                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index    Country_y
# 0         554.594735              NaN          NaN
# 1         621.912414              NaN          NaN
# 2         663.141053              NaN          NaN
# 3         651.987862            4.040  Afghanistan
# 4         628.146804              NaN          NaN
# ...              ...              ...          ...
# 2698             NaN            6.014   Uzbekistan
# 2699             NaN            5.211    Venezuela
# 2700             NaN            5.763      Vietnam
# 2701             NaN            3.982       Zambia
# 2702             NaN            3.204     Zimbabwe
#
# [2703 rows x 10 columns]

# %%
merged4_df.isna().sum()
# Out:
# Country_x                                     165
# Region                                        165
# ISO                                             0
# Year                                            0
# Individuals using the Internet, total (%)     400
# GNI per capita                                296
# GINI Index                                   1821
# GDP Per Capita                                236
# Happiness Index                              1192
# Country_y                                    1192
# dtype: int64

# %% [markdown]
# Need to fill the countries / rows which were added through the happiness index dataset and are missing regions and country names in the main country column

# %%
country_info_dict = dict(zip(internet_gni_gini_gdp_df['ISO'], zip(internet_gni_gini_gdp_df['Country'], internet_gni_gini_gdp_df['Region'])))
country_info_dict

for index, row in merged4_df.iterrows():
    iso = row["ISO"]
    if iso in country_info_dict:
        country_name, region = country_info_dict[iso]
        if pd.isnull(row["Country_x"]):
            merged4_df.at[index, "Country_x"] = country_name
        if pd.isnull(row["Region"]):
            merged4_df.at[index, "Region"] = region
        if pd.isnull(row["ISO"]):
            merged4_df.at[index, "ISO"] = iso_code

merged4_df
# Out:
#         Country_x          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2698   Uzbekistan             CIS  UZB  2023
# 2699    Venezuela    The Americas  VEN  2023
# 2700     Viet Nam  Asia & Pacific  VNM  2023
# 2701       Zambia          Africa  ZMB  2023
# 2702     Zimbabwe          Africa  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2698                                        NaN             NaN         NaN
# 2699                                        NaN             NaN         NaN
# 2700                                        NaN             NaN         NaN
# 2701                                        NaN             NaN         NaN
# 2702                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index    Country_y
# 0         554.594735              NaN          NaN
# 1         621.912414              NaN          NaN
# 2         663.141053              NaN          NaN
# 3         651.987862            4.040  Afghanistan
# 4         628.146804              NaN          NaN
# ...              ...              ...          ...
# 2698             NaN            6.014   Uzbekistan
# 2699             NaN            5.211    Venezuela
# 2700             NaN            5.763      Vietnam
# 2701             NaN            3.982       Zambia
# 2702             NaN            3.204     Zimbabwe
#
# [2703 rows x 10 columns]

# %%
merged4_df.isna().sum()
# Out:
# Country_x                                      31
# Region                                         31
# ISO                                             0
# Year                                            0
# Individuals using the Internet, total (%)     400
# GNI per capita                                296
# GINI Index                                   1821
# GDP Per Capita                                236
# Happiness Index                              1192
# Country_y                                    1192
# dtype: int64

# %% [markdown]
# There are still 31 lines for countries which weren't matched with previous ISO codes

# %%
merged4_df[merged4_df["Country_x"].isnull()]
# Out:
#      Country_x Region  ISO  Year  Individuals using the Internet, total (%)  \
# 2603       NaN    NaN  KOS  2013                                        NaN
# 2604       NaN    NaN  KOS  2015                                        NaN
# 2605       NaN    NaN  KOS  2016                                        NaN
# 2606       NaN    NaN  KOS  2017                                        NaN
# 2607       NaN    NaN  KOS  2018                                        NaN
# ...        ...    ...  ...   ...                                        ...
# 2681       NaN    NaN  TWN  2019                                        NaN
# 2682       NaN    NaN  TWN  2020                                        NaN
# 2683       NaN    NaN  TWN  2021                                        NaN
# 2684       NaN    NaN  TWN  2022                                        NaN
# 2685       NaN    NaN  TWN  2023                                        NaN
#
#       GNI per capita  GINI Index  GDP Per Capita  Happiness Index Country_y
# 2603             NaN         NaN             NaN            5.222    Kosovo
# 2604             NaN         NaN             NaN            5.589    Kosovo
# 2605             NaN         NaN             NaN            5.401    Kosovo
# 2606             NaN         NaN             NaN            5.279    Kosovo
# 2607             NaN         NaN             NaN            5.662    Kosovo
# ...              ...         ...             ...              ...       ...
# 2681             NaN         NaN             NaN            6.446    Taiwan
# 2682             NaN         NaN             NaN            6.455    Taiwan
# 2683             NaN         NaN             NaN            6.584    Taiwan
# 2684             NaN         NaN             NaN            6.512    Taiwan
# 2685             NaN         NaN             NaN            6.535    Taiwan
#
# [31 rows x 10 columns]

# %% [markdown]
# Again these are countries which don't appear in the world bank data set so we'll need to drop them

# %%
merged4_df = merged4_df.dropna(subset=['Country_x', 'Region'], how='any')
merged4_df = merged4_df.drop(columns=['Country_y'])
internet_gni_gini_gdp_hap_df = merged4_df.rename(columns={'Country_x': 'Country'})
internet_gni_gini_gdp_hap_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2698   Uzbekistan             CIS  UZB  2023
# 2699    Venezuela    The Americas  VEN  2023
# 2700     Viet Nam  Asia & Pacific  VNM  2023
# 2701       Zambia          Africa  ZMB  2023
# 2702     Zimbabwe          Africa  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2698                                        NaN             NaN         NaN
# 2699                                        NaN             NaN         NaN
# 2700                                        NaN             NaN         NaN
# 2701                                        NaN             NaN         NaN
# 2702                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index
# 0         554.594735              NaN
# 1         621.912414              NaN
# 2         663.141053              NaN
# 3         651.987862            4.040
# 4         628.146804              NaN
# ...              ...              ...
# 2698             NaN            6.014
# 2699             NaN            5.211
# 2700             NaN            5.763
# 2701             NaN            3.982
# 2702             NaN            3.204
#
# [2672 rows x 9 columns]

# %%
internet_gni_gini_gdp_hap_df.shape
# Out:
# (2672, 9)

# %% [markdown]
# At the end of this section the final dataframe is called internet_gni_gini_gdp_hap_df

# %% [markdown]
# ## Literacy Rates <a name="literacyratescleaning"></a>
# Pulling in and setting up the data via an api on the Literacy Rates by country by year.

# %%
url = 'http://api.worldbank.org/v2/country/all/indicator/SE.ADT.LITR.ZS?format=json&page='

all_data = []
page = 1

while True:
    response = requests.get(url + str(page))
    data = response.json()

    if data[0]['page'] >= data[0]['pages']:
        break

    all_data.extend(data[1])
    page += 1

print(len(all_data))
# Out:
# 16750

# %%
df = pd.DataFrame(all_data)
df['date'] = df['date'].astype(int)
df.dtypes
# Out:
# indicator           object
# country             object
# countryiso3code     object
# date                 int64
# value              float64
# unit                object
# obs_status          object
# decimal              int64
# dtype: object

# %% [markdown]
# Getting rid of data before 2010 to match with the remaining datasets

# %%
pd.set_option('display.max_rows', 10)
df_reduced = df[df["date"]>=2010]
df_reduced
# Out:
#                                                indicator  \
# 0      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 1      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 2      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 3      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 4      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# ...                                                  ...
# 16703  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16704  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16705  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16706  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16707  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal
# 0      2022  72.600403                        0
# 1      2021  72.581161                        0
# 2      2020  72.785622                        0
# 3      2019  72.634972                        0
# 4      2018  71.392616                        0
# ...     ...        ...  ...        ...      ...
# 16703  2014  88.693420                        0
# 16704  2013        NaN                        0
# 16705  2012        NaN                        0
# 16706  2011  83.582710                        0
# 16707  2010        NaN                        0
#
# [3458 rows x 8 columns]

# %% [markdown]
# Pulling out the name from the dictionary value in the country column

# %%
df_reduced['Country'] = df['country'].apply(lambda x: x['value'])
df_reduced
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/2594793725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced['Country'] = df['country'].apply(lambda x: x['value'])
#                                                indicator  \
# 0      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 1      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 2      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 3      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 4      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# ...                                                  ...
# 16703  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16704  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16705  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16706  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16707  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal                      Country
# 0      2022  72.600403                        0  Africa Eastern and Southern
# 1      2021  72.581161                        0  Africa Eastern and Southern
# 2      2020  72.785622                        0  Africa Eastern and Southern
# 3      2019  72.634972                        0  Africa Eastern and Southern
# 4      2018  71.392616                        0  Africa Eastern and Southern
# ...     ...        ...  ...        ...      ...                          ...
# 16703  2014  88.693420                        0                     Zimbabwe
# 16704  2013        NaN                        0                     Zimbabwe
# 16705  2012        NaN                        0                     Zimbabwe
# 16706  2011  83.582710                        0                     Zimbabwe
# 16707  2010        NaN                        0                     Zimbabwe
#
# [3458 rows x 9 columns]

# %%
df_reduced.dropna(subset=['value'], inplace=True)
df_reduced.rename(columns={'date': 'Year'}, inplace=True)
df_reduced.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
df_reduced
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3283445406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced.dropna(subset=['value'], inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3283445406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced.rename(columns={'date': 'Year'}, inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3283445406.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
#                                                indicator  \
# 0      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 1      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 2      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 3      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 4      {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# ...                                                  ...
# 16634  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16644  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16695  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16703  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
# 16706  {'id': 'SE.ADT.LITR.ZS', 'value': 'Literacy ra...
#
#                                                  country  ISO  Year  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2022
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2021
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2020
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2019
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2018
# ...                                                  ...  ...   ...
# 16634                    {'id': 'ZM', 'value': 'Zambia'}  ZMB  2020
# 16644                    {'id': 'ZM', 'value': 'Zambia'}  ZMB  2010
# 16695                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2022
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2014
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2011
#
#            value unit obs_status  decimal                      Country
# 0      72.600403                        0  Africa Eastern and Southern
# 1      72.581161                        0  Africa Eastern and Southern
# 2      72.785622                        0  Africa Eastern and Southern
# 3      72.634972                        0  Africa Eastern and Southern
# 4      71.392616                        0  Africa Eastern and Southern
# ...          ...  ...        ...      ...                          ...
# 16634  87.500000                        0                       Zambia
# 16644  83.007668                        0                       Zambia
# 16695  89.849998                        0                     Zimbabwe
# 16703  88.693420                        0                     Zimbabwe
# 16706  83.582710                        0                     Zimbabwe
#
# [1023 rows x 9 columns]

# %%
merged5_df = pd.merge(internet_gni_gini_gdp_hap_df, df_reduced[['ISO', 'Year', 'value']], on=['ISO', 'Year'], how='left')
merged5_df.rename(columns={'value': 'Literacy'}, inplace=True)
merged5_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2667   Uzbekistan             CIS  UZB  2023
# 2668    Venezuela    The Americas  VEN  2023
# 2669     Viet Nam  Asia & Pacific  VNM  2023
# 2670       Zambia          Africa  ZMB  2023
# 2671     Zimbabwe          Africa  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2667                                        NaN             NaN         NaN
# 2668                                        NaN             NaN         NaN
# 2669                                        NaN             NaN         NaN
# 2670                                        NaN             NaN         NaN
# 2671                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy
# 0         554.594735              NaN        NaN
# 1         621.912414              NaN  31.448851
# 2         663.141053              NaN        NaN
# 3         651.987862            4.040        NaN
# 4         628.146804              NaN        NaN
# ...              ...              ...        ...
# 2667             NaN            6.014        NaN
# 2668             NaN            5.211        NaN
# 2669             NaN            5.763        NaN
# 2670             NaN            3.982        NaN
# 2671             NaN            3.204        NaN
#
# [2672 rows x 10 columns]

# %%
internet_gni_gini_gdp_hap_lit_df = merged5_df.copy()

# %%
internet_gni_gini_gdp_hap_lit_df.shape
# Out:
# (2672, 10)

# %% [markdown]
# The final dataset after this section is called internet_gni_gini_gdp_hap_lit_df

# %% [markdown]
# ## Suicide Rates <a name="suicideratescleaning"></a>
# Pulling in and setting up the data via an api on the Suicide Rates by country by year.

# %%
url = 'http://api.worldbank.org/v2/country/all/indicator/SH.STA.SUIC.P5?format=json&page='

all_data = []
page = 1

while True:
    response = requests.get(url + str(page))
    data = response.json()

    if data[0]['page'] >= data[0]['pages']:
        break

    all_data.extend(data[1])
    page += 1

print(len(all_data))
# Out:
# 16750

# %%
df2 = pd.DataFrame(all_data)
df2['date'] = df2['date'].astype(int)
df2.dtypes
# Out:
# indicator           object
# country             object
# countryiso3code     object
# date                 int64
# value              float64
# unit                object
# obs_status          object
# decimal              int64
# dtype: object

# %%
pd.set_option('display.max_rows', 10)
df_reduced2 = df2[df2["date"]>=2010]
df_reduced2
# Out:
#                                                indicator  \
# 0      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 1      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 2      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 3      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 4      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# ...                                                  ...
# 16703  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16704  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16705  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16706  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16707  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal
# 0      2022        NaN                        1
# 1      2021        NaN                        1
# 2      2020        NaN                        1
# 3      2019   8.024906                        1
# 4      2018   8.118032                        1
# ...     ...        ...  ...        ...      ...
# 16703  2014  18.200000                        1
# 16704  2013  18.600000                        1
# 16705  2012  19.700000                        1
# 16706  2011  20.700000                        1
# 16707  2010  21.500000                        1
#
# [3458 rows x 8 columns]

# %%
df_reduced2['Country'] = df2['country'].apply(lambda x: x['value'])
df_reduced2
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/3746184579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced2['Country'] = df2['country'].apply(lambda x: x['value'])
#                                                indicator  \
# 0      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 1      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 2      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 3      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 4      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# ...                                                  ...
# 16703  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16704  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16705  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16706  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16707  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal                      Country
# 0      2022        NaN                        1  Africa Eastern and Southern
# 1      2021        NaN                        1  Africa Eastern and Southern
# 2      2020        NaN                        1  Africa Eastern and Southern
# 3      2019   8.024906                        1  Africa Eastern and Southern
# 4      2018   8.118032                        1  Africa Eastern and Southern
# ...     ...        ...  ...        ...      ...                          ...
# 16703  2014  18.200000                        1                     Zimbabwe
# 16704  2013  18.600000                        1                     Zimbabwe
# 16705  2012  19.700000                        1                     Zimbabwe
# 16706  2011  20.700000                        1                     Zimbabwe
# 16707  2010  21.500000                        1                     Zimbabwe
#
# [3458 rows x 9 columns]

# %%
df_reduced2.dropna(subset=['value'], inplace=True)
df_reduced2.rename(columns={'date': 'Year'}, inplace=True)
df_reduced2.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
df_reduced2
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1834253825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced2.dropna(subset=['value'], inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1834253825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced2.rename(columns={'date': 'Year'}, inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1834253825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced2.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
#                                                indicator  \
# 3      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 4      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 5      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 6      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 7      {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# ...                                                  ...
# 16703  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16704  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16705  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16706  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
# 16707  {'id': 'SH.STA.SUIC.P5', 'value': 'Suicide mor...
#
#                                                  country  ISO  Year  \
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2019
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2018
# 5      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2017
# 6      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2016
# 7      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2015
# ...                                                  ...  ...   ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2014
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2013
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2012
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2011
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2010
#
#            value unit obs_status  decimal                      Country
# 3       8.024906                        1  Africa Eastern and Southern
# 4       8.118032                        1  Africa Eastern and Southern
# 5       8.232943                        1  Africa Eastern and Southern
# 6       8.328658                        1  Africa Eastern and Southern
# 7       8.489758                        1  Africa Eastern and Southern
# ...          ...  ...        ...      ...                          ...
# 16703  18.200000                        1                     Zimbabwe
# 16704  18.600000                        1                     Zimbabwe
# 16705  19.700000                        1                     Zimbabwe
# 16706  20.700000                        1                     Zimbabwe
# 16707  21.500000                        1                     Zimbabwe
#
# [2310 rows x 9 columns]

# %%
merged6_df = pd.merge(internet_gni_gini_gdp_hap_lit_df, df_reduced2[['ISO', 'Year', 'value']], on=['ISO', 'Year'], how='left')
merged6_df.rename(columns={'value': 'Suicide Rates'}, inplace=True)
merged6_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2667   Uzbekistan             CIS  UZB  2023
# 2668    Venezuela    The Americas  VEN  2023
# 2669     Viet Nam  Asia & Pacific  VNM  2023
# 2670       Zambia          Africa  ZMB  2023
# 2671     Zimbabwe          Africa  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2667                                        NaN             NaN         NaN
# 2668                                        NaN             NaN         NaN
# 2669                                        NaN             NaN         NaN
# 2670                                        NaN             NaN         NaN
# 2671                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy  Suicide Rates
# 0         554.594735              NaN        NaN            4.3
# 1         621.912414              NaN  31.448851            4.1
# 2         663.141053              NaN        NaN            4.0
# 3         651.987862            4.040        NaN            4.0
# 4         628.146804              NaN        NaN            3.9
# ...              ...              ...        ...            ...
# 2667             NaN            6.014        NaN            NaN
# 2668             NaN            5.211        NaN            NaN
# 2669             NaN            5.763        NaN            NaN
# 2670             NaN            3.982        NaN            NaN
# 2671             NaN            3.204        NaN            NaN
#
# [2672 rows x 11 columns]

# %%
internet_gni_gini_gdp_hap_lit_sui_df = merged6_df.copy()

# %%
internet_gni_gini_gdp_hap_lit_sui_df.shape
# Out:
# (2672, 11)

# %% [markdown]
# The final dataset after this section is called internet_gni_gini_gdp_hap_lit_sui_df

# %% [markdown]
# ## CO2 Emissions <a name="co2cleaning"></a>
# Pulling in and setting up the data via an api on the CO2 Emissions by country by year.

# %%
url = 'http://api.worldbank.org/v2/country/all/indicator/EN.ATM.CO2E.PC?format=json&page='

all_data = []
page = 1

while True:
    response = requests.get(url + str(page))
    data = response.json()

    if data[0]['page'] >= data[0]['pages']:
        break

    all_data.extend(data[1])
    page += 1

print(len(all_data))
# Out:
# 16750

# %%
df3 = pd.DataFrame(all_data)
df3['date'] = df3['date'].astype(int)
df3.dtypes
# Out:
# indicator           object
# country             object
# countryiso3code     object
# date                 int64
# value              float64
# unit                object
# obs_status          object
# decimal              int64
# dtype: object

# %%
pd.set_option('display.max_rows', 10)
df_reduced3 = df3[df3["date"]>=2010]
df_reduced3
# Out:
#                                                indicator  \
# 0      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 1      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 2      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 3      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 4      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# ...                                                  ...
# 16703  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16704  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16705  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16706  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16707  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date     value unit obs_status  decimal
# 0      2022       NaN                        1
# 1      2021       NaN                        1
# 2      2020  0.795420                        1
# 3      2019  0.915294                        1
# 4      2018  0.921453                        1
# ...     ...       ...  ...        ...      ...
# 16703  2014  0.866838                        1
# 16704  2013  0.901248                        1
# 16705  2012  0.901214                        1
# 16706  2011  0.871932                        1
# 16707  2010  0.741290                        1
#
# [3458 rows x 8 columns]

# %%
df_reduced3['Country'] = df3['country'].apply(lambda x: x['value'])
df_reduced3
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/2051446966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced3['Country'] = df3['country'].apply(lambda x: x['value'])
#                                                indicator  \
# 0      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 1      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 2      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 3      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 4      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# ...                                                  ...
# 16703  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16704  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16705  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16706  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16707  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# ...                                                  ...             ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date     value unit obs_status  decimal                      Country
# 0      2022       NaN                        1  Africa Eastern and Southern
# 1      2021       NaN                        1  Africa Eastern and Southern
# 2      2020  0.795420                        1  Africa Eastern and Southern
# 3      2019  0.915294                        1  Africa Eastern and Southern
# 4      2018  0.921453                        1  Africa Eastern and Southern
# ...     ...       ...  ...        ...      ...                          ...
# 16703  2014  0.866838                        1                     Zimbabwe
# 16704  2013  0.901248                        1                     Zimbabwe
# 16705  2012  0.901214                        1                     Zimbabwe
# 16706  2011  0.871932                        1                     Zimbabwe
# 16707  2010  0.741290                        1                     Zimbabwe
#
# [3458 rows x 9 columns]

# %%
df_reduced3.dropna(subset=['value'], inplace=True)
df_reduced3.rename(columns={'date': 'Year'}, inplace=True)
df_reduced3.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
df_reduced3
# Out:
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1901030127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced3.dropna(subset=['value'], inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1901030127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced3.rename(columns={'date': 'Year'}, inplace=True)
# /var/folders/v4/fzvn3vnd4jg427pq437v42j80000gn/T/ipykernel_79599/1901030127.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced3.rename(columns={'countryiso3code': 'ISO'}, inplace=True)
#                                                indicator  \
# 2      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 3      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 4      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 5      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 6      {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# ...                                                  ...
# 16703  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16704  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16705  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16706  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
# 16707  {'id': 'EN.ATM.CO2E.PC', 'value': 'CO2 emissio...
#
#                                                  country  ISO  Year     value  \
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2020  0.795420
# 3      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2019  0.915294
# 4      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2018  0.921453
# 5      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2017  0.933874
# 6      {'id': 'ZH', 'value': 'Africa Eastern and Sout...  AFE  2016  0.941337
# ...                                                  ...  ...   ...       ...
# 16703                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2014  0.866838
# 16704                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2013  0.901248
# 16705                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2012  0.901214
# 16706                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2011  0.871932
# 16707                  {'id': 'ZW', 'value': 'Zimbabwe'}  ZWE  2010  0.741290
#
#       unit obs_status  decimal                      Country
# 2                            1  Africa Eastern and Southern
# 3                            1  Africa Eastern and Southern
# 4                            1  Africa Eastern and Southern
# 5                            1  Africa Eastern and Southern
# 6                            1  Africa Eastern and Southern
# ...    ...        ...      ...                          ...
# 16703                        1                     Zimbabwe
# 16704                        1                     Zimbabwe
# 16705                        1                     Zimbabwe
# 16706                        1                     Zimbabwe
# 16707                        1                     Zimbabwe
#
# [2629 rows x 9 columns]

# %%
merged7_df = pd.merge(internet_gni_gini_gdp_hap_lit_sui_df, df_reduced3[['ISO', 'Year', 'value']], on=['ISO', 'Year'], how='left')
merged7_df.rename(columns={'value': 'CO2 Emissions'}, inplace=True)
merged7_df
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2667   Uzbekistan             CIS  UZB  2023
# 2668    Venezuela    The Americas  VEN  2023
# 2669     Viet Nam  Asia & Pacific  VNM  2023
# 2670       Zambia          Africa  ZMB  2023
# 2671     Zimbabwe          Africa  ZWE  2023
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2667                                        NaN             NaN         NaN
# 2668                                        NaN             NaN         NaN
# 2669                                        NaN             NaN         NaN
# 2670                                        NaN             NaN         NaN
# 2671                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy  Suicide Rates  CO2 Emissions
# 0         554.594735              NaN        NaN            4.3       0.304230
# 1         621.912414              NaN  31.448851            4.1       0.408965
# 2         663.141053              NaN        NaN            4.0       0.335061
# 3         651.987862            4.040        NaN            4.0       0.298088
# 4         628.146804              NaN        NaN            3.9       0.283692
# ...              ...              ...        ...            ...            ...
# 2667             NaN            6.014        NaN            NaN            NaN
# 2668             NaN            5.211        NaN            NaN            NaN
# 2669             NaN            5.763        NaN            NaN            NaN
# 2670             NaN            3.982        NaN            NaN            NaN
# 2671             NaN            3.204        NaN            NaN            NaN
#
# [2672 rows x 12 columns]

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_df = merged7_df.copy()

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_df.shape
# Out:
# (2672, 12)

# %% [markdown]
# After this section the final dataset is called internet_gni_gini_gdp_hap_lit_sui_CO2_df

# %% [markdown]
# ## Internet Price <a name="ipcleaning"></a>

# %%
ip_file_path = 'data/internet_price_2021.csv'
ip_df = pd.read_csv(ip_file_path)

# Melt the dataset to convert columns with years into rows
melted = ip_df.melt(id_vars=['City', 'Region', 'Country'], var_name='Year', value_name='Internet_Price')

# Remove rows where 'Internet_Price' is 0 (assuming these are missing values)
melted = melted[melted['Internet_Price'] != 0]

melted.drop(['City', 'Region'], axis=1, inplace=True)

melted['Year'] = melted['Year'].str.split(', ').str[1]
melted['Year'] = melted['Year'].astype(int)

median_ip = melted.groupby(['Country', 'Year'], as_index=False)['Internet_Price'].median()
median_ip = median_ip.sort_values(by=['Year', 'Country'])
median_ip.reset_index(drop=True, inplace=True)

median_ip
# Out:
#                      Country  Year  Internet_Price
# 0                  Argentina  2010       34.594820
# 1                  Australia  2010       42.372881
# 2                    Austria  2010       43.209877
# 3     Bosnia and Herzegovina  2010       21.399177
# 4                     Brazil  2010       34.340659
# ...                      ...   ...             ...
# 1018                 Uruguay  2020       31.760326
# 1019              Uzbekistan  2020       33.555714
# 1020               Venezuela  2020        9.112500
# 1021                 Vietnam  2020       10.573918
# 1022                Zimbabwe  2020      104.833333
#
# [1023 rows x 3 columns]

# %% [markdown]
# Now we need to add ISO codes before merging with the main database to avoid mismatches due to different country names.

# %%
country_names = pd.read_csv("data/any_name_to_wb_name.csv")
iso_codes = pd.read_csv("data/iso3_to_wb_name.csv")
country_names
# Out:
#                                   any      wb_name
# 0                         Afghanistan  Afghanistan
# 1    Afghanistan, islamic republic of  Afghanistan
# 2                       Aland Islands          NaN
# 3                               Aland          NaN
# 4                             Albania      Albania
# ..                                ...          ...
# 406                             Yemen  Yemen, Rep.
# 407                Yemen, republic of  Yemen, Rep.
# 408                       Yemen, Rep.  Yemen, Rep.
# 409                            Zambia       Zambia
# 410                          Zimbabwe     Zimbabwe
#
# [411 rows x 2 columns]

# %%
ip_merge_names = pd.merge(median_ip, country_names, how="left", left_on="Country", right_on="any")
list_missing = ip_merge_names[ip_merge_names["wb_name"].isnull()]
countries = list_missing["Country"].unique()
countries
# Out:
# array(["People's Republic of China", 'North Macedonia'], dtype=object)

# %%
new_rows = [
    {'any': "People's Republic of China", 'wb_name': 'China'},
    {'any': 'North Macedonia', 'wb_name': "Macedonia, FYR"}
]

new_rows_df = pd.DataFrame(new_rows)

country_names = pd.concat([country_names, new_rows_df], ignore_index=True)

# %% [markdown]
# Rerunning the merger now to check that all countries have been matched to World Bank spelling of names:

# %%
ip_merge_names = pd.merge(median_ip, country_names, how="left", left_on="Country", right_on="any")
list_missing = ip_merge_names[ip_merge_names["wb_name"].isnull()]
countries = list_missing["Country"].unique()
countries
# Out:
# array([], dtype=object)

# %%
iso_codes.rename(columns={'country': 'Country WB Name'}, inplace=True)
iso_codes
# Out:
#     iso3 Country WB Name
# 0    ABW           Aruba
# 1    AFG     Afghanistan
# 2    AGO          Angola
# 3    AIA        Anguilla
# 4    ALB         Albania
# ..   ...             ...
# 216  WSM           Samoa
# 217  YEM     Yemen, Rep.
# 218  ZAF    South Africa
# 219  ZMB          Zambia
# 220  ZWE        Zimbabwe
#
# [221 rows x 2 columns]

# %%
ip_merge_iso = pd.merge(ip_merge_names, iso_codes, how="left", left_on="wb_name", right_on="Country WB Name")
ip_merge_iso.rename(columns={'iso3': 'ISO'}, inplace=True)
ip_merge_iso
# Out:
#                      Country  Year  Internet_Price                     any  \
# 0                  Argentina  2010       34.594820               Argentina
# 1                  Australia  2010       42.372881               Australia
# 2                    Austria  2010       43.209877                 Austria
# 3     Bosnia and Herzegovina  2010       21.399177  Bosnia and Herzegovina
# 4                     Brazil  2010       34.340659                  Brazil
# ...                      ...   ...             ...                     ...
# 1018                 Uruguay  2020       31.760326                 Uruguay
# 1019              Uzbekistan  2020       33.555714              Uzbekistan
# 1020               Venezuela  2020        9.112500               Venezuela
# 1021                 Vietnam  2020       10.573918                 Vietnam
# 1022                Zimbabwe  2020      104.833333                Zimbabwe
#
#                      wb_name  ISO         Country WB Name
# 0                  Argentina  ARG               Argentina
# 1                  Australia  AUS               Australia
# 2                    Austria  AUT                 Austria
# 3     Bosnia and Herzegovina  BIH  Bosnia and Herzegovina
# 4                     Brazil  BRA                  Brazil
# ...                      ...  ...                     ...
# 1018                 Uruguay  URY                 Uruguay
# 1019              Uzbekistan  UZB              Uzbekistan
# 1020           Venezuela, RB  VEN           Venezuela, RB
# 1021                 Vietnam  VNM                 Vietnam
# 1022                Zimbabwe  ZWE                Zimbabwe
#
# [1023 rows x 7 columns]

# %%
# Merge the datasets
merged = pd.merge(internet_gni_gini_gdp_hap_lit_sui_CO2_df, ip_merge_iso[["Internet_Price", "ISO", "Year"]], on=['ISO', 'Year'], how='outer')
merged['Internet Price Ratio'] = 100* merged['Internet_Price'] / merged['GNI per capita']
merged
# Out:
#           Country          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2678          NaN             NaN  TWN  2016
# 2679          NaN             NaN  TWN  2017
# 2680          NaN             NaN  TWN  2018
# 2681          NaN             NaN  TWN  2019
# 2682          NaN             NaN  TWN  2020
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2678                                        NaN             NaN         NaN
# 2679                                        NaN             NaN         NaN
# 2680                                        NaN             NaN         NaN
# 2681                                        NaN             NaN         NaN
# 2682                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy  Suicide Rates  \
# 0         554.594735              NaN        NaN            4.3
# 1         621.912414              NaN  31.448851            4.1
# 2         663.141053              NaN        NaN            4.0
# 3         651.987862             4.04        NaN            4.0
# 4         628.146804              NaN        NaN            3.9
# ...              ...              ...        ...            ...
# 2678             NaN              NaN        NaN            NaN
# 2679             NaN              NaN        NaN            NaN
# 2680             NaN              NaN        NaN            NaN
# 2681             NaN              NaN        NaN            NaN
# 2682             NaN              NaN        NaN            NaN
#
#       CO2 Emissions  Internet_Price  Internet Price Ratio
# 0          0.304230             NaN                   NaN
# 1          0.408965             NaN                   NaN
# 2          0.335061             NaN                   NaN
# 3          0.298088             NaN                   NaN
# 4          0.283692             NaN                   NaN
# ...             ...             ...                   ...
# 2678            NaN       25.015246                   NaN
# 2679            NaN       24.924705                   NaN
# 2680            NaN       31.594986                   NaN
# 2681            NaN       21.669785                   NaN
# 2682            NaN       20.121383                   NaN
#
# [2683 rows x 14 columns]

# %% [markdown]
# Again there are a few rows with countries that doesn't appear in the World Bank datasets so we will drop those.

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_price_df = merged.dropna(subset=['Country'])

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_price_df.shape
# Out:
# (2672, 14)

# %% [markdown]
# At the end of this section the dataset is called internet_gni_gini_gdp_hap_lit_sui_CO2_price_df

# %% [markdown]
# ## Voter Turnout <a name = "VoterTurnout"></a>

# %%
voter_turnout_df = pd.read_excel("data/idea_export_voter_turnout_database_world.xlsx")
voter_turnout_df.head()
# Out:
#        Country ISO2 ISO3        year Voter Turnout
# 0  Afghanistan   AF  AFG  2018-01-01        45.23%
# 1  Afghanistan   AF  AFG  2010-01-01        35.14%
# 2  Afghanistan   AF  AFG  2005-01-01        49.37%
# 3  Afghanistan   AF  AFG  2005-01-01        49.37%
# 4      Albania   AL  ALB  2021-01-01        46.32%

# %% [markdown]
# ### Make sure the data in the columns are mergeable <a name ="renameAndReformatData"></a>

# %%
#I need to change the year column to include only the first four characters to show the year.
voter_turnout_df['year'] = voter_turnout_df['year'].str[:4]
voter_turnout_df['year']
# Out:
# 0       2018
# 1       2010
# 2       2005
# 3       2005
# 4       2021
#         ...
# 2324    2000
# 2325    1995
# 2326    1979
# 2327    2013
# 2328    2023
# Name: year, Length: 2329, dtype: object

# %%
#The output type is object, therefore it will need to be changed to Int64 in order to be merged with the main data set.
voter_turnout_df['year'] = voter_turnout_df['year'].astype('int64')

voter_turnout_df['year'].dtypes
# Out:
# dtype('int64')

# %%
# I need to remove all years before 2010 as these are not considered in the main data set
voter_turnout_df = voter_turnout_df[voter_turnout_df['year'] >= 2010]

#Check that the function has worked correctly.
voter_turnout_df
# Out:
#           Country ISO2 ISO3  year Voter Turnout
# 0     Afghanistan   AF  AFG  2018        45.23%
# 1     Afghanistan   AF  AFG  2010        35.14%
# 4         Albania   AL  ALB  2021        46.32%
# 5         Albania   AL  ALB  2017        46.76%
# 6         Albania   AL  ALB  2013        53.31%
# ...           ...  ...  ...   ...           ...
# 2314       Zambia   ZM  ZMB  2016        56.03%
# 2315       Zambia   ZM  ZMB  2011        53.65%
# 2321     Zimbabwe   ZW  ZWE  2018        83.10%
# 2327     Zimbabwe   ZW  ZWE  2013        57.78%
# 2328     Zimbabwe   ZW  ZWE  2023        67.37%
#
# [622 rows x 5 columns]

# %% [markdown]
# ### Remove NaN data <a name="RemoveNaNs"></a>

# %%
#Display all Na and Null data values
nan_count_per_column = voter_turnout_df.isna().sum()

# Print the count of NaN values in each column
print(nan_count_per_column)
# Out:
# Country          0
# ISO2             2
# ISO3             5
# year             0
# Voter Turnout    0
# dtype: int64

# %%
# Display what the NaNs are for ISO3 because we will want to merge on them later.

nan_rows = voter_turnout_df[voter_turnout_df.isna().any(axis=1)]

# Print the rows with NaN values
nan_rows
# Out:
#       Country ISO2 ISO3  year Voter Turnout
# 1227   Kosovo   KV  NaN  2021        48.84%
# 1228   Kosovo   KV  NaN  2019        43.20%
# 1229   Kosovo   KV  NaN  2017        41.30%
# 1230   Kosovo   KV  NaN  2014        42.63%
# 1231   Kosovo   KV  NaN  2010        45.62%
# 1513  Namibia  NaN  NAM  2019        60.38%
# 1514  Namibia  NaN  NAM  2014        72.00%

# %% [markdown]
# ### Remove Unecessary columns from the data <a name ="removecolumns"></a>

# %%
#Drop the ISO2 column now, as it is the only column with NaNs and it is not needed for the analysis as we will use ISO3 for the merge.
voter_turnout_df.drop(columns=['ISO2'], inplace=True)
voter_turnout_df
# Out:
#           Country ISO3  year Voter Turnout
# 0     Afghanistan  AFG  2018        45.23%
# 1     Afghanistan  AFG  2010        35.14%
# 4         Albania  ALB  2021        46.32%
# 5         Albania  ALB  2017        46.76%
# 6         Albania  ALB  2013        53.31%
# ...           ...  ...   ...           ...
# 2314       Zambia  ZMB  2016        56.03%
# 2315       Zambia  ZMB  2011        53.65%
# 2321     Zimbabwe  ZWE  2018        83.10%
# 2327     Zimbabwe  ZWE  2013        57.78%
# 2328     Zimbabwe  ZWE  2023        67.37%
#
# [622 rows x 4 columns]

# %%
#I need to rename ISO3 to ISO in order to complete the merge.
voter_turnout_df = voter_turnout_df.rename(columns={'ISO3': 'ISO'})

voter_turnout_df
# Out:
#           Country  ISO  year Voter Turnout
# 0     Afghanistan  AFG  2018        45.23%
# 1     Afghanistan  AFG  2010        35.14%
# 4         Albania  ALB  2021        46.32%
# 5         Albania  ALB  2017        46.76%
# 6         Albania  ALB  2013        53.31%
# ...           ...  ...   ...           ...
# 2314       Zambia  ZMB  2016        56.03%
# 2315       Zambia  ZMB  2011        53.65%
# 2321     Zimbabwe  ZWE  2018        83.10%
# 2327     Zimbabwe  ZWE  2013        57.78%
# 2328     Zimbabwe  ZWE  2023        67.37%
#
# [622 rows x 4 columns]

# %%
#I need to rename year to Year in order to complete the merge.

voter_turnout_df = voter_turnout_df.rename(columns={'year': 'Year'})
voter_turnout_df
# Out:
#           Country  ISO  Year Voter Turnout
# 0     Afghanistan  AFG  2018        45.23%
# 1     Afghanistan  AFG  2010        35.14%
# 4         Albania  ALB  2021        46.32%
# 5         Albania  ALB  2017        46.76%
# 6         Albania  ALB  2013        53.31%
# ...           ...  ...   ...           ...
# 2314       Zambia  ZMB  2016        56.03%
# 2315       Zambia  ZMB  2011        53.65%
# 2321     Zimbabwe  ZWE  2018        83.10%
# 2327     Zimbabwe  ZWE  2013        57.78%
# 2328     Zimbabwe  ZWE  2023        67.37%
#
# [622 rows x 4 columns]

# %%
#Need Voter Turnout as a float as currently will not be able to merge.
voter_turnout_df['Voter Turnout'] = voter_turnout_df['Voter Turnout'].str.rstrip('%')

voter_turnout_df['Voter Turnout'] = pd.to_numeric(voter_turnout_df['Voter Turnout'], errors='coerce')
voter_turnout_df
# Out:
#           Country  ISO  Year  Voter Turnout
# 0     Afghanistan  AFG  2018          45.23
# 1     Afghanistan  AFG  2010          35.14
# 4         Albania  ALB  2021          46.32
# 5         Albania  ALB  2017          46.76
# 6         Albania  ALB  2013          53.31
# ...           ...  ...   ...            ...
# 2314       Zambia  ZMB  2016          56.03
# 2315       Zambia  ZMB  2011          53.65
# 2321     Zimbabwe  ZWE  2018          83.10
# 2327     Zimbabwe  ZWE  2013          57.78
# 2328     Zimbabwe  ZWE  2023          67.37
#
# [622 rows x 4 columns]

# %% [markdown]
# ### Merge this data set with the main <a name="mergewithmain"></a>

# %%
#Merge the dataSets
merged_df = pd.merge(internet_gni_gini_gdp_hap_lit_sui_CO2_price_df,voter_turnout_df[["Voter Turnout", "Country","Year", "ISO"]], left_on = ['ISO', 'Year'],right_on =['ISO', 'Year'], how ='outer')
merged_df
# Out:
#         Country_x          Region  ISO  Year  \
# 0     Afghanistan  Asia & Pacific  AFG  2010
# 1     Afghanistan  Asia & Pacific  AFG  2011
# 2     Afghanistan  Asia & Pacific  AFG  2012
# 3     Afghanistan  Asia & Pacific  AFG  2013
# 4     Afghanistan  Asia & Pacific  AFG  2014
# ...           ...             ...  ...   ...
# 2723          NaN             NaN  TKM  2023
# 2724          NaN             NaN  VGB  2023
# 2725          NaN             NaN  VGB  2019
# 2726          NaN             NaN  VGB  2015
# 2727          NaN             NaN  VGB  2011
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2723                                        NaN             NaN         NaN
# 2724                                        NaN             NaN         NaN
# 2725                                        NaN             NaN         NaN
# 2726                                        NaN             NaN         NaN
# 2727                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy  Suicide Rates  \
# 0         554.594735              NaN        NaN            4.3
# 1         621.912414              NaN  31.448851            4.1
# 2         663.141053              NaN        NaN            4.0
# 3         651.987862             4.04        NaN            4.0
# 4         628.146804              NaN        NaN            3.9
# ...              ...              ...        ...            ...
# 2723             NaN              NaN        NaN            NaN
# 2724             NaN              NaN        NaN            NaN
# 2725             NaN              NaN        NaN            NaN
# 2726             NaN              NaN        NaN            NaN
# 2727             NaN              NaN        NaN            NaN
#
#       CO2 Emissions  Internet_Price  Internet Price Ratio  Voter Turnout  \
# 0          0.304230             NaN                   NaN          35.14
# 1          0.408965             NaN                   NaN            NaN
# 2          0.335061             NaN                   NaN            NaN
# 3          0.298088             NaN                   NaN            NaN
# 4          0.283692             NaN                   NaN            NaN
# ...             ...             ...                   ...            ...
# 2723            NaN             NaN                   NaN          91.12
# 2724            NaN             NaN                   NaN          57.50
# 2725            NaN             NaN                   NaN          64.64
# 2726            NaN             NaN                   NaN          66.58
# 2727            NaN             NaN                   NaN          72.85
#
#                     Country_y
# 0                 Afghanistan
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 2723             Turkmenistan
# 2724  Virgin Islands, British
# 2725  Virgin Islands, British
# 2726  Virgin Islands, British
# 2727  Virgin Islands, British
#
# [2728 rows x 16 columns]

# %%
pd.set_option('display.max_rows', 10)
country_info_dict = dict(zip(internet_gni_gini_gdp_hap_lit_sui_CO2_price_df['ISO'], zip(internet_gni_gini_gdp_hap_lit_sui_CO2_price_df['Country'], internet_gni_gini_gdp_hap_lit_sui_CO2_price_df['Region'])))
country_info_dict

for index, row in merged_df.iterrows():
    iso = row["ISO"]
    if iso in country_info_dict:
        country_name, region = country_info_dict[iso]
        if pd.isnull(row["Country_x"]):
            merged_df.at[index, "Country_x"] = country_name
        if pd.isnull(row["Region"]):
            merged_df.at[index, "Region"] = region
        if pd.isnull(row["ISO"]):
            merged_df.at[index, "ISO"] = iso_code

merged_df
# Out:
#          Country_x          Region  ISO  Year  \
# 0      Afghanistan  Asia & Pacific  AFG  2010
# 1      Afghanistan  Asia & Pacific  AFG  2011
# 2      Afghanistan  Asia & Pacific  AFG  2012
# 3      Afghanistan  Asia & Pacific  AFG  2013
# 4      Afghanistan  Asia & Pacific  AFG  2014
# ...            ...             ...  ...   ...
# 2723  Turkmenistan             CIS  TKM  2023
# 2724           NaN             NaN  VGB  2023
# 2725           NaN             NaN  VGB  2019
# 2726           NaN             NaN  VGB  2015
# 2727           NaN             NaN  VGB  2011
#
#       Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                      4.000000           520.0         NaN
# 1                                      5.000000           550.0         NaN
# 2                                      5.454545           650.0         NaN
# 3                                      5.900000           680.0         NaN
# 4                                      7.000000           650.0         NaN
# ...                                         ...             ...         ...
# 2723                                        NaN             NaN         NaN
# 2724                                        NaN             NaN         NaN
# 2725                                        NaN             NaN         NaN
# 2726                                        NaN             NaN         NaN
# 2727                                        NaN             NaN         NaN
#
#       GDP Per Capita  Happiness Index   Literacy  Suicide Rates  \
# 0         554.594735              NaN        NaN            4.3
# 1         621.912414              NaN  31.448851            4.1
# 2         663.141053              NaN        NaN            4.0
# 3         651.987862             4.04        NaN            4.0
# 4         628.146804              NaN        NaN            3.9
# ...              ...              ...        ...            ...
# 2723             NaN              NaN        NaN            NaN
# 2724             NaN              NaN        NaN            NaN
# 2725             NaN              NaN        NaN            NaN
# 2726             NaN              NaN        NaN            NaN
# 2727             NaN              NaN        NaN            NaN
#
#       CO2 Emissions  Internet_Price  Internet Price Ratio  Voter Turnout  \
# 0          0.304230             NaN                   NaN          35.14
# 1          0.408965             NaN                   NaN            NaN
# 2          0.335061             NaN                   NaN            NaN
# 3          0.298088             NaN                   NaN            NaN
# 4          0.283692             NaN                   NaN            NaN
# ...             ...             ...                   ...            ...
# 2723            NaN             NaN                   NaN          91.12
# 2724            NaN             NaN                   NaN          57.50
# 2725            NaN             NaN                   NaN          64.64
# 2726            NaN             NaN                   NaN          66.58
# 2727            NaN             NaN                   NaN          72.85
#
#                     Country_y
# 0                 Afghanistan
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 2723             Turkmenistan
# 2724  Virgin Islands, British
# 2725  Virgin Islands, British
# 2726  Virgin Islands, British
# 2727  Virgin Islands, British
#
# [2728 rows x 16 columns]

# %%
pd.set_option('display.max_rows', None)
filtered_df = merged_df[merged_df["Country_x"].isnull()]
unique_country_y_count = filtered_df['Country_y'].value_counts()
unique_country_y_count
# Out:
# Country_y
# Kosovo                     5
# Cook Islands               4
# Gibraltar                  4
# Virgin Islands, British    4
# Anguilla                   3
# Aruba                      3
# Bermuda                    3
# Cayman Islands             3
# Greenland                  3
# Taiwan                     3
# Faroe Islands              2
# Montserrat                 2
# Palau                      2
# Name: count, dtype: int64

# %% [markdown]
# All territories and countries which don't appear in the world bank dataset, dropping them for the time being.

# %%
merged_df.dropna(subset=['Country_x'], inplace=True)
merged_df.drop(columns=['Country_y'], inplace=True)
merged_df.rename(columns={'Country_x': 'Country'}, inplace=True)

# %%
#Create a copy from which you can create the CSV
internet_gni_gini_gdp_hap_lit_sui_CO2_price_voterdb_df = merged_df.copy()

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_price_voterdb_df.shape
# Out:
# (2687, 15)

# %% [markdown]
# ## DataFrame and Export <a name="finalexport"></a>
# Exporting dataframe to csv.

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_price_voterdb_df.to_csv('internet_and_development_13122023.csv', index=False)

# %%
internet_gni_gini_gdp_hap_lit_sui_CO2_price_voterdb_df.head()
# Out:
#        Country          Region  ISO  Year  \
# 0  Afghanistan  Asia & Pacific  AFG  2010
# 1  Afghanistan  Asia & Pacific  AFG  2011
# 2  Afghanistan  Asia & Pacific  AFG  2012
# 3  Afghanistan  Asia & Pacific  AFG  2013
# 4  Afghanistan  Asia & Pacific  AFG  2014
#
#    Individuals using the Internet, total (%)  GNI per capita  GINI Index  \
# 0                                   4.000000           520.0         NaN
# 1                                   5.000000           550.0         NaN
# 2                                   5.454545           650.0         NaN
# 3                                   5.900000           680.0         NaN
# 4                                   7.000000           650.0         NaN
#
#    GDP Per Capita  Happiness Index   Literacy  Suicide Rates  CO2 Emissions  \
# 0      554.594735              NaN        NaN            4.3       0.304230
# 1      621.912414              NaN  31.448851            4.1       0.408965
# 2      663.141053              NaN        NaN            4.0       0.335061
# 3      651.987862             4.04        NaN            4.0       0.298088
# 4      628.146804              NaN        NaN            3.9       0.283692
#
#    Internet_Price  Internet Price Ratio  Voter Turnout
# 0             NaN                   NaN          35.14
# 1             NaN                   NaN            NaN
# 2             NaN                   NaN            NaN
# 3             NaN                   NaN            NaN
# 4             NaN                   NaN            NaN
